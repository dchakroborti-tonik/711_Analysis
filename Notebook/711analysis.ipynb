# %% [markdown]
# # <div align="center" style="color: #ff5733;">7 11 Data Analysis</div>

# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.

# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
path = r'C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
# Example: pd.set_option('display.max_columns', None)

# %%
sq = """with mb as 
(select customer_id, right(new_mobile_number, 10) mobile from `risk_credit_mis.customer_contact_details`
union all 
select customer_id, right(old_mobile_number, 10) mobile from `risk_credit_mis.customer_contact_details` where old_mobile_number is not null
),
mb1 
as
(select distinct customer_id, mobile from mb),
mb2
as
(select *, row_number() over(partition by customer_id order by customer_id) custrank from mb1),
delqb as
(Select lmt.customerId, case when a1.obs_min_inst_def30 = 3 then lmt.customerId end obsfstpd30 
, case when a1.min_inst_def30 in (1,2,3) then lmt.customerId end fstpd30dev
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data a1
left join `risk_credit_mis.loan_master_table` lmt on lmt.loanAccountNumber = a1.loanAccountNumber
),delqb1 
as
(select customerId, 
max(case when obsfstpd30 is not null and fstpd30dev is not null then 1 else 0 end) fstpd30def,
max(case when obsfstpd30 is not null then 1 else 0 end) obsfpd30
from delqb where obsfstpd30 is not null
group by 1
),
base as
(select * from 
`prj-prod-dataplatform.manual_source_extracts.partner_711_payment_transcation_backtest_20240125` a1
left join mb2 on cast(mb2.mobile as numeric) = cast(a1.mobile_num as numeric)
left join delqb1 on delqb1.customerId = cast(mb2.customer_id as numeric)
)
select * from base"""
df = client.query(sq).to_dataframe(progress_bar_type='tqdm')
# Out:
# Job ID 1004b073-0d60-48ef-adc9-2f398ad70f4e successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
print(f"The shape of the dataset is:\t {df.shape}")
# Out:
# The shape of the dataset is:	 (1196007, 13)

# %%
df.columns
# Out:
# Index(['mobile_num', 'txn_id', 'amount', 'sector', 'merchant_name',
#        'txn_datetime', 'store_id', 'customer_id', 'mobile', 'custrank',
#        'customerId', 'fstpd30def', 'obsfpd30'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196007 entries, 0 to 1196006
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   mobile_num     1196007 non-null  Int64
#  1   txn_id         1196007 non-null  Int64
#  2   amount         1196007 non-null  float64
#  3   sector         1196007 non-null  object
#  4   merchant_name  1196007 non-null  object
#  5   txn_datetime   1196007 non-null  datetime64[us, UTC]
#  6   store_id       1196007 non-null  Int64
#  7   customer_id    1157200 non-null  Int64
#  8   mobile         1157200 non-null  object
#  9   custrank       1157200 non-null  Int64
#  10  customerId     14062 non-null    Int64
#  11  fstpd30def     14062 non-null    Int64
#  12  obsfpd30       14062 non-null    Int64
# dtypes: Int64(8), datetime64[us, UTC](1), float64(1), object(3)
# memory usage: 127.7+ MB

# %%
df['mobile_num'] = df['mobile_num'].astype(str)

# %%
df['sector'].value_counts()
# Out:
# sector
# EMI                       831125
# Loans                     149071
# Bank                       76768
# Prepaid Load               65593
# Postpaid Land Lines        12963
# Transpo or Toll            11468
# Government                 10260
# Utility-Water               8992
# Internet                    7733
# Remittance                  3897
# Utility-Power               3036
# Credit Card                 2908
# Cable TV                    2823
# Postpaid Mobile             2634
# E-Commerce                  1864
# E-Wallet                    1238
# Airlines                     983
# Gaming                       916
# Collections                  498
# Retailer Load                474
# Insurance                    353
# Tuition                      304
# Other Prepaid Services       106
# Name: count, dtype: int64

# %%
# Count matching lp_id with mobile
matching_count = df[df['mobile_num'].isin(df['mobile'])].shape[0]
# Count lp_id that are missing in mobile
missing_count = df[~df['mobile_num'].isin(df['mobile'])].shape[0]

# Total number of lp_id records
total_lp_id = df.shape[0]

# Calculate share of lp_id in mobile
share_in_mobile = (matching_count / total_lp_id) * 100

print(f"Number of lp_id matching with mobile: {matching_count}")
print(f"Number of lp_id missing in mobile: {missing_count}")
print(f"Share of lp_id in mobile: {share_in_mobile:.2f}%")
# Out:
# Number of lp_id matching with mobile: 1157200
# Number of lp_id missing in mobile: 38807
# Share of lp_id in mobile: 96.76%

# %%
df[df['mobile_num'].isin(df['mobile'])].to_csv("Matchingmobilenumberwithoutdatabase.csv", index = False)

# %%
df[~df['mobile_num'].isin(df['mobile'])].to_csv("Missingmobilenumberfromourdatabasewhenmatchingwith711data.csv", index = False)

# %%
df[~df['mobile_num'].isin(df['mobile'])]
# Out:
#          mobile_num      txn_id   amount        sector         merchant_name  \
# 12       9066910733   741088575    170.0    Government                   NBI
# 13       9066910733   621632785    170.0    Government                   NBI
# 14       9062812704   609031332    170.0    Government                   NBI
# 127      9061418598   831583166   8120.0         Loans                  TALA
# 128      9061418598   831583897   9020.0         Loans                  TALA
# ...             ...         ...      ...           ...                   ...
# 1195607  9277742582   592888031  10000.0         Loans          DRAGON LOANS
# 1195608  9277742582   592886779  10000.0         Loans          DRAGON LOANS
# 1195609  9277742582   592888559   2692.0         Loans          DRAGON LOANS
# 1195799  9483115809   600479344    115.0  Prepaid Load     SMART REGULAR 115
# 1195905  9550734916  2151612440     20.0  Prepaid Load  TM ALL IN SURF 20 FB
#
#                      txn_datetime  store_id  customer_id mobile  custrank  \
# 12      2022-02-10 02:12:46+00:00      1594         <NA>   None      <NA>
# 13      2021-08-04 18:51:50+00:00      1869         <NA>   None      <NA>
# 14      2021-07-12 18:26:38+00:00      2682         <NA>   None      <NA>
# 127     2022-07-08 17:57:06+00:00       206         <NA>   None      <NA>
# 128     2022-07-08 17:58:18+00:00       206         <NA>   None      <NA>
# ...                           ...       ...          ...    ...       ...
# 1195607 2021-06-13 03:27:48+00:00      3323         <NA>   None      <NA>
# 1195608 2021-06-12 23:56:59+00:00      3323         <NA>   None      <NA>
# 1195609 2021-06-12 23:58:07+00:00      3323         <NA>   None      <NA>
# 1195799 2021-06-26 19:14:17+00:00      2917         <NA>   None      <NA>
# 1195905 2023-01-19 05:57:31+00:00      3397         <NA>   None      <NA>
#
#          customerId  fstpd30def  obsfpd30
# 12             <NA>        <NA>      <NA>
# 13             <NA>        <NA>      <NA>
# 14             <NA>        <NA>      <NA>
# 127            <NA>        <NA>      <NA>
# 128            <NA>        <NA>      <NA>
# ...             ...         ...       ...
# 1195607        <NA>        <NA>      <NA>
# 1195608        <NA>        <NA>      <NA>
# 1195609        <NA>        <NA>      <NA>
# 1195799        <NA>        <NA>      <NA>
# 1195905        <NA>        <NA>      <NA>
#
# [38807 rows x 13 columns]

# %%
# Get unique lp_id and mobile values
unique_lp_ids = df['mobile_num'].unique()
unique_mobiles = df['mobile'].unique()

# Count how many unique lp_id values are in unique mobiles
matching_count = sum(lp_id in unique_mobiles for lp_id in unique_lp_ids)

# Total number of unique lp_id records
total_unique_lp_id = len(unique_lp_ids)

# Calculate share of unique lp_id in unique mobiles
share_in_mobile = (matching_count / total_unique_lp_id) * 100

print(f"Number of unique lp_id matching with unique mobile: {matching_count}")
print(f"Total number of unique lp_id: {total_unique_lp_id}")
print(f"Share of unique lp_id in unique mobile: {share_in_mobile:.2f}%")
# Out:
# Number of unique lp_id matching with unique mobile: 58522
# Total number of unique lp_id: 60686
# Share of unique lp_id in unique mobile: 96.43%

# %%
df.columns
# Out:
# Index(['mobile_num', 'txn_id', 'amount', 'sector', 'merchant_name',
#        'txn_datetime', 'store_id', 'customer_id', 'mobile', 'custrank',
#        'customerId', 'fstpd30def', 'obsfpd30'],
#       dtype='object')

# %%
# Calculate sector-wise default rate
sector_default_rate = df.groupby('sector').apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())

# Calculate count of unique customers per sector
unique_customers_count = df.groupby('sector')['customer_id'].nunique()
unique_711mobile_count = df.groupby('sector')['mobile_num'].nunique()
unique_obsfstpd30_customer_count = df.groupby('sector')['customerId'].nunique()

# Combine results into a DataFrame
result_df = pd.DataFrame({
    'Sector': sector_default_rate.index,
    'Default Rate (%)': sector_default_rate.values * 100,
    'Unique Customers Count': unique_customers_count,
    'unique 711mobile count': unique_711mobile_count,
    'Observed fstpd30 customer count': unique_obsfstpd30_customer_count,
})

# Sort by Default Rate in descending order
result_df_sorted = result_df.sort_values(by='Default Rate (%)', ascending=False)

print("Sector-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):")
sector_result = result_df_sorted.copy()
sector_result
# Out:
# C:\Users\DwaipayanChakroborti\AppData\Local\Temp\ipykernel_14964\2263231737.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   sector_default_rate = df.groupby('sector').apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())
# C:\Users\DwaipayanChakroborti\AppData\Local\Temp\ipykernel_14964\2263231737.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sector_default_rate = df.groupby('sector').apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())
# Sector-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):
#                                         Sector  Default Rate (%)  \
# sector
# Government                          Government         35.294118
# Insurance                            Insurance         33.333333
# Utility-Power                    Utility-Power         25.000000
# Prepaid Load                      Prepaid Load         14.710042
# Airlines                              Airlines         12.500000
# EMI                                        EMI         11.227098
# Cable TV                              Cable TV         10.000000
# Utility-Water                    Utility-Water          6.716418
# Internet                              Internet          6.666667
# Postpaid Land Lines        Postpaid Land Lines          6.532663
# E-Commerce                          E-Commerce          5.000000
# Remittance                          Remittance          4.838710
# Loans                                    Loans          2.795527
# Bank                                      Bank          1.974865
# E-Wallet                              E-Wallet          0.000000
# Postpaid Mobile                Postpaid Mobile          0.000000
# Transpo or Toll                Transpo or Toll          0.000000
# Tuition                                Tuition          0.000000
# Credit Card                        Credit Card          0.000000
# Collections                        Collections               NaN
# Gaming                                  Gaming               NaN
# Other Prepaid Services  Other Prepaid Services               NaN
# Retailer Load                    Retailer Load               NaN
#
#                         Unique Customers Count  unique 711mobile count  \
# sector
# Government                                6310                    6530
# Insurance                                   67                      71
# Utility-Power                              889                     923
# Prepaid Load                             15559                   16077
# Airlines                                   625                     656
# EMI                                      57736                   59864
# Cable TV                                   771                     798
# Utility-Water                             2683                    2790
# Internet                                  2147                    2218
# Postpaid Land Lines                       3273                    3373
# E-Commerce                                 768                     808
# Remittance                                1234                    1280
# Loans                                    15353                   15997
# Bank                                      4041                    4234
# E-Wallet                                   382                     393
# Postpaid Mobile                            665                     694
# Transpo or Toll                           1783                    1832
# Tuition                                    119                     121
# Credit Card                                657                     681
# Collections                                 82                      84
# Gaming                                      98                     100
# Other Prepaid Services                      49                      50
# Retailer Load                               43                      44
#
#                         Observed fstpd30 customer count
# sector
# Government                                           92
# Insurance                                             2
# Utility-Power                                         6
# Prepaid Load                                        181
# Airlines                                             14
# EMI                                                 856
# Cable TV                                             10
# Utility-Water                                        38
# Internet                                             27
# Postpaid Land Lines                                  47
# E-Commerce                                           10
# Remittance                                           17
# Loans                                               170
# Bank                                                 40
# E-Wallet                                              2
# Postpaid Mobile                                      10
# Transpo or Toll                                      21
# Tuition                                               3
# Credit Card                                          10
# Collections                                           0
# Gaming                                                0
# Other Prepaid Services                                0
# Retailer Load                                         0

# %%
# Calculate sector-wise and merchant-wise default rates
sector_merchant_default_rate = df.groupby(['sector', 'merchant_name']).apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())

# Calculate count of unique customers per sector and merchant
unique_customers_count = df.groupby(['sector', 'merchant_name'])['customer_id'].nunique()
unique_711mobile_count = df.groupby(['sector', 'merchant_name'])['mobile_num'].nunique()
unique_obsfstpd30_customer_count = df.groupby(['sector', 'merchant_name'])['customerId'].nunique()

# Combine results into a DataFrame
result_df = pd.DataFrame({
    'Sector': sector_merchant_default_rate.index.get_level_values(0),
    'Merchant': sector_merchant_default_rate.index.get_level_values(1),
    'Default Rate (%)': sector_merchant_default_rate.values * 100,
    'Unique Customers Count': unique_customers_count,
    'unique 711mobile count': unique_711mobile_count,
    'Observed fstpd30 customer count': unique_obsfstpd30_customer_count,
})

# Sort by Default Rate in descending order
result_df_sorted = result_df.sort_values(by='Default Rate (%)', ascending=False)

pd.set_option('display.max_rows', None)
print("Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):")
sector_merchant_result = result_df_sorted.copy()
sector_merchant_result
# Out:
# C:\Users\DwaipayanChakroborti\AppData\Local\Temp\ipykernel_14964\229032578.py:2: RuntimeWarning: invalid value encountered in scalar divide
#   sector_merchant_default_rate = df.groupby(['sector', 'merchant_name']).apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())
# C:\Users\DwaipayanChakroborti\AppData\Local\Temp\ipykernel_14964\229032578.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sector_merchant_default_rate = df.groupby(['sector', 'merchant_name']).apply(lambda x: x['fstpd30def'].sum() / x['obsfpd30'].sum())
# Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):
#                                                                                  Sector  \
# sector                 merchant_name
# Prepaid Load           UNLICALL 15                                         Prepaid Load
#                        TNT Giga Video 99                                   Prepaid Load
# Utility-Power          MECO                                               Utility-Power
# Prepaid Load           SUNXPRESSLOAD 300                                   Prepaid Load
# Utility-Power          BATELEC1                                           Utility-Power
# Prepaid Load           TM EZ70                                             Prepaid Load
# Loans                  MALAYAN BANK                                               Loans
# Utility-Water          PRIMEWATER                                         Utility-Water
# Government             DFA                                                   Government
#                        BUREAU OF QUARANTINE                                  Government
# Prepaid Load           TM ALL IN SURF 20 FB                                Prepaid Load
#                        SMART REGULAR 30                                    Prepaid Load
#                        SMART REGULAR 60                                    Prepaid Load
# Postpaid Land Lines    GLOBELINES                                   Postpaid Land Lines
# Insurance              AXAPHIL                                                Insurance
# Airlines               PHILIPPINEAIRLINES                                      Airlines
# Cable TV               SKYCABLE                                                Cable TV
# Prepaid Load           GLOBE GO+99                                         Prepaid Load
#                        GLOBE 100                                           Prepaid Load
#                        SUNXPRESSLOAD 100                                   Prepaid Load
# Government             NSOHELPLINE.COM                                       Government
# Prepaid Load           GLOBE Autoload                                      Prepaid Load
#                        TM EASYSURF 50                                      Prepaid Load
#                        GIGA SURF 99                                        Prepaid Load
# Loans                  ACOM                                                       Loans
# EMI                    HELLO MONEY                                                  EMI
# Government             NBI                                                   Government
#                        MYEG PH                                               Government
# Prepaid Load           TM SURF4ALL99TM                                     Prepaid Load
# EMI                    GCash                                                        EMI
# Airlines               CEBUPACIFIC                                             Airlines
# Prepaid Load           GLOBE GOSURF 50                                     Prepaid Load
#                        GIGA SURF 50                                        Prepaid Load
#                        TM ALL IN SURF 30                                   Prepaid Load
# Internet               CONVERGEICT                                             Internet
# Loans                  TALA                                                       Loans
# E-Commerce             SHOPEE                                                E-Commerce
# Prepaid Load           GLOBE GOSAKTO 90                                    Prepaid Load
# Remittance             Palawan Padala                                        Remittance
# Postpaid Land Lines    PLDT                                         Postpaid Land Lines
# EMI                    SHOPEEPAY (DRAGONPAY)                                        EMI
# Loans                  HOME CREDIT                                                Loans
# Bank                   UNIONBANK                                                   Bank
# Loans                  DRAGON LOANS                                               Loans
# Transpo or Toll        EASYTRIP                                         Transpo or Toll
# Utility-Water          SB FINANCE                                         Utility-Water
#                        SOUTH LUZON WATER                                  Utility-Water
# Prepaid Load           GLOBE SURF4ALL99GP                                  Prepaid Load
# Utility-Water          STALUCIA                                           Utility-Water
# Prepaid Load           SMART REGULAR 115                                   Prepaid Load
#                        SMART REGULAR 500                                   Prepaid Load
# Utility-Water          TAGUM WATER                                        Utility-Water
# Prepaid Load           GLOBE SURF4ALL249GP                                 Prepaid Load
# Utility-Water          WATERS PH                                          Utility-Water
# Prepaid Load           GLOBE GOSAKTO 140                                   Prepaid Load
#                        SMART REGULAR 300                                   Prepaid Load
# Utility-Water          MANILAWATER                                        Utility-Water
#                        METRO ROXAS WATER DISTRICT                         Utility-Water
# Prepaid Load           SUN XPRESSLOAD 25                                   Prepaid Load
# Utility-Water          MAYNILAD                                           Utility-Water
# Prepaid Load           SUNXPRESSLOAD 30                                    Prepaid Load
# Utility-Water          LAGUNA WATER                                       Utility-Water
#                        BULACAN WATER                                      Utility-Water
# Utility-Power          VECO                                               Utility-Power
#                        PELCO 3                                            Utility-Power
# Prepaid Load           TNT Giga Video 50                                   Prepaid Load
# Utility-Power          CEBECO 3                                           Utility-Power
# Tuition                DRAGON SCHOOLS                                           Tuition
# Prepaid Load           TNT Surf Saya 99                                    Prepaid Load
#                        TOUCHMOBILE 30                                      Prepaid Load
#                        GLOBE GO90                                          Prepaid Load
# Transpo or Toll        RFID                                             Transpo or Toll
# Prepaid Load           GLOBE GOSAKTO 120                                   Prepaid Load
#                        DITO E-LOAD 200                                     Prepaid Load
#                        GLOBE GO50                                          Prepaid Load
# Credit Card            SBC MASTERCARD PESO                                  Credit Card
# Loans                  AeonCredit                                                 Loans
# Government             MULTIPAY (MANILA)                                     Government
# EMI                    Paymaya                                                      EMI
#                        Lazada                                                       EMI
#                        GRAB                                                         EMI
#                        Coins.ph                                                     EMI
# E-Wallet               PISOPAY                                                 E-Wallet
# E-Commerce             DRAGON PAY                                            E-Commerce
#                        AGODA                                                 E-Commerce
# Credit Card            ROBINSONBANK CREDITCARD                              Credit Card
# Prepaid Load           GLOBE GO140                                         Prepaid Load
# Credit Card            METROBANK                                            Credit Card
#                        BPI CREDITCARD                                       Credit Card
# Cable TV               PLANET CABLE / MEDIASCAPE-CIGNAL                        Cable TV
#                        FIL PRODUCTS                                            Cable TV
#                        BINANGONAN CABLE TV CORP                                Cable TV
# Bank                   DISKARTECH 5001 to 15000                                    Bank
#                        DISKARTECH 15001 to 25000                                   Bank
#                        DISKARTECH 1 to 5000                                        Bank
#                        CIMB                                                        Bank
# Loans                  CASHALO                                                    Loans
#                        FILPROGRESS CREDIT                                         Loans
#                        FLEXI FINANCE                                              Loans
#                        FastLoan                                                   Loans
# Prepaid Load           GLOBE GO120                                         Prepaid Load
#                        GLOBE GO+149                                        Prepaid Load
#                        GLOBE Autoload 350                                  Prepaid Load
#                        GLOBE 500                                           Prepaid Load
#                        GLOBE 50                                            Prepaid Load
#                        DITO E-LOAD 100                                     Prepaid Load
#                        ALL OUT SURF 30                                     Prepaid Load
# Postpaid Mobile        SUNCELLULAR                                      Postpaid Mobile
#                        SMART                                            Postpaid Mobile
#                        GHPHONE                                          Postpaid Mobile
# Loans                  ZURICH                                                     Loans
#                        SUMISHO                                                    Loans
#                        SKYPAY                                                     Loans
#                        Plentina                                                   Loans
#                        PSBANK LOAN                                                Loans
#                        PAYSO                                                      Loans
#                        PAYEXPRESS LOAN                                            Loans
#                        NWOW                                                       Loans
#                        MITSUKOSHI                                                 Loans
# Utility-Water          ePRIME                                             Utility-Water
# Airlines               PAL (OTP Booking)                                       Airlines
# Bank                   MAYBANK                                                     Bank
# Cable TV               ASIAN VISION CABLE                                      Cable TV
#                        BICOL ONE BROADBAND SERVICE                             Cable TV
#                        Bills Payment - Royal Cable                             Cable TV
#                        CABLELINK                                               Cable TV
#                        CENTRALLUZONCABLETV                                     Cable TV
#                        DASCA CABLE SERVICES INC                                Cable TV
#                        GALAXY CABLE                                            Cable TV
#                        JMD CABLE NETWORK                                       Cable TV
#                        KABAYAN CABLE CORP                                      Cable TV
#                        PARASAT                                                 Cable TV
#                        PLANET CABLE                                            Cable TV
#                        SKYLINE CATV INDUSTRIES INC                             Cable TV
#                        SOUTH LUZON CABLE                                       Cable TV
#                        USATV                                                   Cable TV
# Collections            ANJELMAN                                             Collections
#                        APMC                                                 Collections
#                        Bills Payment - Honeycomb                            Collections
#                        CAD REALTY                                           Collections
#                        CBN ASIA                                             Collections
#                        DINGDONG                                             Collections
#                        Donation Key (GOLDEN HAVEN)                          Collections
#                        GREENWEATH DEVELOPMENT CORP.                         Collections
#                        JACQMAN                                              Collections
#                        JOHNDORF                                             Collections
#                        LOADMANNA, INC.                                      Collections
#                        MASTERMAN                                            Collections
#                        NETPLAY INC                                          Collections
#                        PAYCOOLS                                             Collections
#                        PAYEXPRESS TICKETS                                   Collections
#                        PERSONAL COLLECTION                                  Collections
#                        RAYMOND REALTY                                       Collections
#                        RS MANAGEMENT                                        Collections
#                        SMARTMAN                                             Collections
#                        VIVAMAX INC                                          Collections
#                        VTEC                                                 Collections
# Credit Card            AUB CREDITCARDS                                      Credit Card
#                        BANK OF COMMERCE CREDIT CARD                         Credit Card
#                        CHINABANK CREDITCARD                                 Credit Card
# E-Commerce             NETFLIX DragonPay                                     E-Commerce
# E-Wallet               ABRA                                                    E-Wallet
#                        E-Money - EON                                           E-Wallet
#                        FORTUNE PAY                                             E-Wallet
#                        GETGO                                                   E-Wallet
#                        HOMECREDIT PAY                                          E-Wallet
#                        MAGICPAY                                                E-Wallet
#                        MAXIM                                                   E-Wallet
#                        NETBANK DEPOSIT                                         E-Wallet
#                        YAZZ                                                    E-Wallet
# EMI                    ALLEASY                                                      EMI
#                        RCBC myWallet                                                EMI
#                        TAGCASH                                                      EMI
# Gaming                 DRAGONGAMES                                               Gaming
#                        GAMECLUB 100                                              Gaming
#                        GAMECLUB 20                                               Gaming
#                        GAMECLUB 300                                              Gaming
#                        GAMECLUB 50                                               Gaming
#                        GAMECLUB 500                                              Gaming
#                        GAMETIME                                                  Gaming
#                        GARENA 100                                                Gaming
#                        GARENA 1000                                               Gaming
#                        GARENA 200                                                Gaming
#                        GARENA 300                                                Gaming
#                        GARENA 50                                                 Gaming
#                        GARENA 500                                                Gaming
#                        METROTURF                                                 Gaming
#                        STEAM 120                                                 Gaming
#                        STEAM 2640                                                Gaming
#                        STEAM 299                                                 Gaming
#                        STEAM 599                                                 Gaming
#                        STEAM 60                                                  Gaming
#                        STEAM 960                                                 Gaming
#                        UniPin Voucher 100                                        Gaming
#                        UniPin Voucher 300                                        Gaming
# Government             BSP                                                   Government
#                        MARINA                                                Government
#                        MARINA (PISOPAY)                                      Government
#                        SOCIAL HOUSING FINANCE CORPORATION                    Government
# Insurance              COCOLIFE                                               Insurance
#                        CONNEXT MARKETING                                      Insurance
#                        DIALEX                                                 Insurance
#                        INSULAR LIFE                                           Insurance
#                        PARAMOUNT                                              Insurance
# Internet               BICORE                                                  Internet
#                        WOOFY                                                   Internet
# Loans                  AGRIBANK                                                   Loans
#                        ASIALINK                                                   Loans
#                        BAGUIO BENGUET COMMUNITY CREDIT COOP                       Loans
#                        BANCO ALABANG                                              Loans
#                        CARD BANK INC                                              Loans
#                        CARD INC                                                   Loans
#                        CARD MRI RIZAL BANK                                        Loans
#                        CARD SME BANK                                              Loans
#                        CASHBEE                                                    Loans
#                        CEBU CFI                                                   Loans
#                        CEPAT                                                      Loans
#                        CHAILEASE BERJAYA                                          Loans
#                        CHINATRUST                                                 Loans
#                        COUNTRY FUNDERS                                            Loans
#                        CTFSI                                                      Loans
#                        CVM FINANCE                                                Loans
#                        DS FINANCE                                                 Loans
#                        ENCORE LEASING AND FINANCE CORP                            Loans
#                        FINASWIDE                                                  Loans
#                        FIRST STANDARD                                             Loans
#                        FORBES LENDING                                             Loans
#                        FUNDLINE                                                   Loans
#                        GLOBAL DOMINION                                            Loans
#                        GLOBAL SME LOANS                                           Loans
#                        GRAMEEN PILIPINAS MICROFINANCE                             Loans
#                        INSULAR SAVERS                                             Loans
#                        JUAN CASH                                                  Loans
#                        LENDPINOY                                                  Loans
#                        LOAN STAR                                                  Loans
#                        MEGASAVER                                                  Loans
#                        MOTORSTAR (Probikes)                                       Loans
#                        Motorcentral                                               Loans
#                        NOVADECI                                                   Loans
#                        OLM LENDING                                                Loans
#                        ORICO                                                      Loans
#                        PAYMENT INNOVATION INC. (PAYCOOLS LOANS)                   Loans
#                        PERAJET                                                    Loans
#                        RFC LOAN                                                   Loans
#                        SECOND PAY                                                 Loans
#                        SIMBAYANAN COOP                                            Loans
#                        SOUTH ASIALINK                                             Loans
#                        STO NINO DE CEBU FINANCE                                   Loans
#                        SURECYCLE FINANCE                                          Loans
#                        U PESO LENDING                                             Loans
#                        UNIONBANK QUICKLOANS                                       Loans
# Other Prepaid Services CIGNAL 1000                               Other Prepaid Services
#                        CIGNAL 300                                Other Prepaid Services
#                        CIGNAL 450                                Other Prepaid Services
#                        CIGNAL 600                                Other Prepaid Services
#                        FAMLOAD VIDEO 199                         Other Prepaid Services
#                        FAMLOAD VIDEO 599                         Other Prepaid Services
#                        FAMLOAD VIDEO 999                         Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 199                    Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 999                    Other Prepaid Services
#                        GLOBE HOMESURF 199                        Other Prepaid Services
#                        GLOBE HOMEWATCH 199                       Other Prepaid Services
#                        NETFLIX 1000                              Other Prepaid Services
#                        NETFLIX 459                               Other Prepaid Services
#                        NETFLIX 550                               Other Prepaid Services
# Postpaid Land Lines    BAYANTEL                                     Postpaid Land Lines
# Prepaid Load           CHERRY LOAD 30                                      Prepaid Load
#                        CHERRY LOAD 50                                      Prepaid Load
#                        DITO E-LOAD 300                                     Prepaid Load
#                        DITO E-LOAD 500                                     Prepaid Load
#                        GLOBE 30                                            Prepaid Load
#                        GLOBE 300                                           Prepaid Load
#                        GLOBE 70                                            Prepaid Load
#                        GLOBE AMAX GO UNLI 30                               Prepaid Load
#                        GLOBE GO+129                                        Prepaid Load
#                        GLOBE GO+250                                        Prepaid Load
#                        GLOBE GO+400                                        Prepaid Load
#                        GLOBE GO400                                         Prepaid Load
#                        GRAMEEN PILIPINAS MICROFINANCE                      Prepaid Load
#                        Giga Video+ 149                                     Prepaid Load
#                        SMART GIGA GAMES 99                                 Prepaid Load
#                        SMART GIGA STORIES 299                              Prepaid Load
#                        SMART GIGA STORIES 99                               Prepaid Load
#                        SMART GIGA VIDEO 299                                Prepaid Load
#                        SUN TEXT UNLIMITED 150                              Prepaid Load
#                        SUN TEXT UNLIMITED 50                               Prepaid Load
#                        SUN TU200 200                                       Prepaid Load
#                        SUNXPRESSLOAD 150                                   Prepaid Load
#                        SUNXPRESSLOAD 50                                    Prepaid Load
#                        SUNXPRESSLOAD 75                                    Prepaid Load
#                        TM SURF4ALL249TM                                    Prepaid Load
#                        TNT GIGA VIDEO 299                                  Prepaid Load
#                        TOUCHMOBILE 50                                      Prepaid Load
#                        TOUCHMOBILE 70                                      Prepaid Load
# Retailer Load          GLOBE RETAILER 1000                                Retailer Load
#                        GLOBE RETAILER 1500                                Retailer Load
#                        GLOBE RETAILER 2000                                Retailer Load
#                        GLOBE RETAILER 500                                 Retailer Load
#                        SMART RETAILER 1000                                Retailer Load
#                        SMART RETAILER 1500                                Retailer Load
#                        SMART RETAILER 2000                                Retailer Load
#                        SMART RETAILER 2500                                Retailer Load
#                        SMART RETAILER 500                                 Retailer Load
# Transpo or Toll        BARKOTA                                          Transpo or Toll
# Tuition                GOLDEN FAITH ACADEMY                                     Tuition
#                        ICCT COLLEGES                                            Tuition
#                        NATIONAL TEACHERS COLLEGE                                Tuition
#                        PHINMA EDUCATION                                         Tuition
# Utility-Power          BATELEC2                                           Utility-Power
#                        BENECO                                             Utility-Power
#                        Bills Collection - Angeles Electric                Utility-Power
#                        CAGELCO1                                           Utility-Power
#                        CAPELCO                                            Utility-Power
#                        CASURECO 4                                         Utility-Power
#                        CASURECO2                                          Utility-Power
#                        CASURECO3                                          Utility-Power
#                        CEBECO2                                            Utility-Power
#                        CELCOR                                             Utility-Power
#                        CENPELCO                                           Utility-Power
#                        CEPALCO                                            Utility-Power
#                        COTELCO                                            Utility-Power
#                        DASURECO                                           Utility-Power
#                        DAVAOLIGHT                                         Utility-Power
#                        DECORP                                             Utility-Power
#                        FLECO                                              Utility-Power
#                        ILECO1                                             Utility-Power
#                        ILIGAN LIGHT                                       Utility-Power
#                        INEC                                               Utility-Power
#                        ISECO                                              Utility-Power
#                        LEYECO 2                                           Utility-Power
#                        LIMA ENERZONE                                      Utility-Power
#                        LUELCO                                             Utility-Power
#                        MOELCI 2                                           Utility-Power
#                        MORESCO 1                                          Utility-Power
#                        NEECO1                                             Utility-Power
#                        NEECO2 AREA1                                       Utility-Power
#                        NEECO2 AREA2                                       Utility-Power
#                        NORECO2                                            Utility-Power
#                        NUVELCO                                            Utility-Power
#                        OEDC                                               Utility-Power
#                        PANELCO1                                           Utility-Power
#                        PANELCO3                                           Utility-Power
#                        PELCO 2                                            Utility-Power
#                        PELCO1                                             Utility-Power
#                        PENELCO                                            Utility-Power
#                        PRESCO                                             Utility-Power
#                        QUEZELCO1                                          Utility-Power
#                        SAJELCO                                            Utility-Power
#                        SFELAPCO                                           Utility-Power
#                        SORECO2                                            Utility-Power
#                        SubicEnerzone                                      Utility-Power
#                        TARELCO 1                                          Utility-Power
#                        TARELCO2                                           Utility-Power
#                        TARLAC ELECTRIC INC                                Utility-Power
#                        ZAMECO1                                            Utility-Power
#                        ZAMECO2                                            Utility-Power
# Utility-Water          AQUA CENTRO                                        Utility-Water
#                        BAGUIO WATER                                       Utility-Water
#                        BOCAUE WATER DISTRICT                              Utility-Water
#                        BPWATERWORKS                                       Utility-Water
#                        BULAKAN WATER                                      Utility-Water
#                        BUSTOS WATER DISTRICT                              Utility-Water
#                        CALUMPIT WATER                                     Utility-Water
#                        CANDELARIA WATER DISTRICT                          Utility-Water
#                        CARCAR WATER DISTRICT                              Utility-Water
#                        CDO WATER                                          Utility-Water
#                        CLARK WATER                                        Utility-Water
#                        COUNTRYWIDE WATER SERVICES                         Utility-Water
#                        Dagupan City Water District                        Utility-Water
#                        FIRST PEAK                                         Utility-Water
#                        GENSAN CITY WATER DISTRICT                         Utility-Water
#                        GOODHANDSWATER                                     Utility-Water
#                        HAPPYWELLMANAGEMENT                                Utility-Water
#                        HIYAS WATER                                        Utility-Water
#                        LAGUNA WATER DISTRICT                              Utility-Water
#                        MABALACAT WATER                                    Utility-Water
#                        MACTAN ROCK INDUSTRIES, INC.                       Utility-Water
#                        MANILAWATER PHILVENTURES                           Utility-Water
#                        MCWD (METRO CEBU)                                  Utility-Water
#                        METRO DUMAGUETE WATER                              Utility-Water
#                        METRO LIPA WATER DISTRICT                          Utility-Water
#                        MIWD                                               Utility-Water
#                        OBANDO WATER                                       Utility-Water
#                        PLARIDEL WATER                                     Utility-Water
#                        SUBICWATER                                         Utility-Water
#                        TANAY WATER DISTRICT                               Utility-Water
#                        TERESA WATER DISTRICT                              Utility-Water
#
#                                                                                                  Merchant  \
# sector                 merchant_name
# Prepaid Load           UNLICALL 15                                                            UNLICALL 15
#                        TNT Giga Video 99                                                TNT Giga Video 99
# Utility-Power          MECO                                                                          MECO
# Prepaid Load           SUNXPRESSLOAD 300                                                SUNXPRESSLOAD 300
# Utility-Power          BATELEC1                                                                  BATELEC1
# Prepaid Load           TM EZ70                                                                    TM EZ70
# Loans                  MALAYAN BANK                                                          MALAYAN BANK
# Utility-Water          PRIMEWATER                                                              PRIMEWATER
# Government             DFA                                                                            DFA
#                        BUREAU OF QUARANTINE                                          BUREAU OF QUARANTINE
# Prepaid Load           TM ALL IN SURF 20 FB                                          TM ALL IN SURF 20 FB
#                        SMART REGULAR 30                                                  SMART REGULAR 30
#                        SMART REGULAR 60                                                  SMART REGULAR 60
# Postpaid Land Lines    GLOBELINES                                                              GLOBELINES
# Insurance              AXAPHIL                                                                    AXAPHIL
# Airlines               PHILIPPINEAIRLINES                                              PHILIPPINEAIRLINES
# Cable TV               SKYCABLE                                                                  SKYCABLE
# Prepaid Load           GLOBE GO+99                                                            GLOBE GO+99
#                        GLOBE 100                                                                GLOBE 100
#                        SUNXPRESSLOAD 100                                                SUNXPRESSLOAD 100
# Government             NSOHELPLINE.COM                                                    NSOHELPLINE.COM
# Prepaid Load           GLOBE Autoload                                                      GLOBE Autoload
#                        TM EASYSURF 50                                                      TM EASYSURF 50
#                        GIGA SURF 99                                                          GIGA SURF 99
# Loans                  ACOM                                                                          ACOM
# EMI                    HELLO MONEY                                                            HELLO MONEY
# Government             NBI                                                                            NBI
#                        MYEG PH                                                                    MYEG PH
# Prepaid Load           TM SURF4ALL99TM                                                    TM SURF4ALL99TM
# EMI                    GCash                                                                        GCash
# Airlines               CEBUPACIFIC                                                            CEBUPACIFIC
# Prepaid Load           GLOBE GOSURF 50                                                    GLOBE GOSURF 50
#                        GIGA SURF 50                                                          GIGA SURF 50
#                        TM ALL IN SURF 30                                                TM ALL IN SURF 30
# Internet               CONVERGEICT                                                            CONVERGEICT
# Loans                  TALA                                                                          TALA
# E-Commerce             SHOPEE                                                                      SHOPEE
# Prepaid Load           GLOBE GOSAKTO 90                                                  GLOBE GOSAKTO 90
# Remittance             Palawan Padala                                                      Palawan Padala
# Postpaid Land Lines    PLDT                                                                          PLDT
# EMI                    SHOPEEPAY (DRAGONPAY)                                        SHOPEEPAY (DRAGONPAY)
# Loans                  HOME CREDIT                                                            HOME CREDIT
# Bank                   UNIONBANK                                                                UNIONBANK
# Loans                  DRAGON LOANS                                                          DRAGON LOANS
# Transpo or Toll        EASYTRIP                                                                  EASYTRIP
# Utility-Water          SB FINANCE                                                              SB FINANCE
#                        SOUTH LUZON WATER                                                SOUTH LUZON WATER
# Prepaid Load           GLOBE SURF4ALL99GP                                              GLOBE SURF4ALL99GP
# Utility-Water          STALUCIA                                                                  STALUCIA
# Prepaid Load           SMART REGULAR 115                                                SMART REGULAR 115
#                        SMART REGULAR 500                                                SMART REGULAR 500
# Utility-Water          TAGUM WATER                                                            TAGUM WATER
# Prepaid Load           GLOBE SURF4ALL249GP                                            GLOBE SURF4ALL249GP
# Utility-Water          WATERS PH                                                                WATERS PH
# Prepaid Load           GLOBE GOSAKTO 140                                                GLOBE GOSAKTO 140
#                        SMART REGULAR 300                                                SMART REGULAR 300
# Utility-Water          MANILAWATER                                                            MANILAWATER
#                        METRO ROXAS WATER DISTRICT                              METRO ROXAS WATER DISTRICT
# Prepaid Load           SUN XPRESSLOAD 25                                                SUN XPRESSLOAD 25
# Utility-Water          MAYNILAD                                                                  MAYNILAD
# Prepaid Load           SUNXPRESSLOAD 30                                                  SUNXPRESSLOAD 30
# Utility-Water          LAGUNA WATER                                                          LAGUNA WATER
#                        BULACAN WATER                                                        BULACAN WATER
# Utility-Power          VECO                                                                          VECO
#                        PELCO 3                                                                    PELCO 3
# Prepaid Load           TNT Giga Video 50                                                TNT Giga Video 50
# Utility-Power          CEBECO 3                                                                  CEBECO 3
# Tuition                DRAGON SCHOOLS                                                      DRAGON SCHOOLS
# Prepaid Load           TNT Surf Saya 99                                                  TNT Surf Saya 99
#                        TOUCHMOBILE 30                                                      TOUCHMOBILE 30
#                        GLOBE GO90                                                              GLOBE GO90
# Transpo or Toll        RFID                                                                          RFID
# Prepaid Load           GLOBE GOSAKTO 120                                                GLOBE GOSAKTO 120
#                        DITO E-LOAD 200                                                    DITO E-LOAD 200
#                        GLOBE GO50                                                              GLOBE GO50
# Credit Card            SBC MASTERCARD PESO                                            SBC MASTERCARD PESO
# Loans                  AeonCredit                                                              AeonCredit
# Government             MULTIPAY (MANILA)                                                MULTIPAY (MANILA)
# EMI                    Paymaya                                                                    Paymaya
#                        Lazada                                                                      Lazada
#                        GRAB                                                                          GRAB
#                        Coins.ph                                                                  Coins.ph
# E-Wallet               PISOPAY                                                                    PISOPAY
# E-Commerce             DRAGON PAY                                                              DRAGON PAY
#                        AGODA                                                                        AGODA
# Credit Card            ROBINSONBANK CREDITCARD                                    ROBINSONBANK CREDITCARD
# Prepaid Load           GLOBE GO140                                                            GLOBE GO140
# Credit Card            METROBANK                                                                METROBANK
#                        BPI CREDITCARD                                                      BPI CREDITCARD
# Cable TV               PLANET CABLE / MEDIASCAPE-CIGNAL                  PLANET CABLE / MEDIASCAPE-CIGNAL
#                        FIL PRODUCTS                                                          FIL PRODUCTS
#                        BINANGONAN CABLE TV CORP                                  BINANGONAN CABLE TV CORP
# Bank                   DISKARTECH 5001 to 15000                                  DISKARTECH 5001 to 15000
#                        DISKARTECH 15001 to 25000                                DISKARTECH 15001 to 25000
#                        DISKARTECH 1 to 5000                                          DISKARTECH 1 to 5000
#                        CIMB                                                                          CIMB
# Loans                  CASHALO                                                                    CASHALO
#                        FILPROGRESS CREDIT                                              FILPROGRESS CREDIT
#                        FLEXI FINANCE                                                        FLEXI FINANCE
#                        FastLoan                                                                  FastLoan
# Prepaid Load           GLOBE GO120                                                            GLOBE GO120
#                        GLOBE GO+149                                                          GLOBE GO+149
#                        GLOBE Autoload 350                                              GLOBE Autoload 350
#                        GLOBE 500                                                                GLOBE 500
# ...
#                        FORBES LENDING                                                          0
#                        FUNDLINE                                                                0
#                        GLOBAL DOMINION                                                         0
#                        GLOBAL SME LOANS                                                        0
#                        GRAMEEN PILIPINAS MICROFINANCE                                          0
#                        INSULAR SAVERS                                                          0
#                        JUAN CASH                                                               0
#                        LENDPINOY                                                               0
#                        LOAN STAR                                                               0
#                        MEGASAVER                                                               0
#                        MOTORSTAR (Probikes)                                                    0
#                        Motorcentral                                                            0
#                        NOVADECI                                                                0
#                        OLM LENDING                                                             0
#                        ORICO                                                                   0
#                        PAYMENT INNOVATION INC. (PAYCOOLS LOANS)                                0
#                        PERAJET                                                                 0
#                        RFC LOAN                                                                0
#                        SECOND PAY                                                              0
#                        SIMBAYANAN COOP                                                         0
#                        SOUTH ASIALINK                                                          0
#                        STO NINO DE CEBU FINANCE                                                0
#                        SURECYCLE FINANCE                                                       0
#                        U PESO LENDING                                                          0
#                        UNIONBANK QUICKLOANS                                                    0
# Other Prepaid Services CIGNAL 1000                                                             0
#                        CIGNAL 300                                                              0
#                        CIGNAL 450                                                              0
#                        CIGNAL 600                                                              0
#                        FAMLOAD VIDEO 199                                                       0
#                        FAMLOAD VIDEO 599                                                       0
#                        FAMLOAD VIDEO 999                                                       0
#                        FAMLOAD VIDEO PLUS 199                                                  0
#                        FAMLOAD VIDEO PLUS 999                                                  0
#                        GLOBE HOMESURF 199                                                      0
#                        GLOBE HOMEWATCH 199                                                     0
#                        NETFLIX 1000                                                            0
#                        NETFLIX 459                                                             0
#                        NETFLIX 550                                                             0
# Postpaid Land Lines    BAYANTEL                                                                0
# Prepaid Load           CHERRY LOAD 30                                                          0
#                        CHERRY LOAD 50                                                          0
#                        DITO E-LOAD 300                                                         0
#                        DITO E-LOAD 500                                                         0
#                        GLOBE 30                                                                0
#                        GLOBE 300                                                               0
#                        GLOBE 70                                                                0
#                        GLOBE AMAX GO UNLI 30                                                   0
#                        GLOBE GO+129                                                            0
#                        GLOBE GO+250                                                            0
#                        GLOBE GO+400                                                            0
#                        GLOBE GO400                                                             0
#                        GRAMEEN PILIPINAS MICROFINANCE                                          0
#                        Giga Video+ 149                                                         0
#                        SMART GIGA GAMES 99                                                     0
#                        SMART GIGA STORIES 299                                                  0
#                        SMART GIGA STORIES 99                                                   0
#                        SMART GIGA VIDEO 299                                                    0
#                        SUN TEXT UNLIMITED 150                                                  0
#                        SUN TEXT UNLIMITED 50                                                   0
#                        SUN TU200 200                                                           0
#                        SUNXPRESSLOAD 150                                                       0
#                        SUNXPRESSLOAD 50                                                        0
#                        SUNXPRESSLOAD 75                                                        0
#                        TM SURF4ALL249TM                                                        0
#                        TNT GIGA VIDEO 299                                                      0
#                        TOUCHMOBILE 50                                                          0
#                        TOUCHMOBILE 70                                                          0
# Retailer Load          GLOBE RETAILER 1000                                                     0
#                        GLOBE RETAILER 1500                                                     0
#                        GLOBE RETAILER 2000                                                     0
#                        GLOBE RETAILER 500                                                      0
#                        SMART RETAILER 1000                                                     0
#                        SMART RETAILER 1500                                                     0
#                        SMART RETAILER 2000                                                     0
#                        SMART RETAILER 2500                                                     0
#                        SMART RETAILER 500                                                      0
# Transpo or Toll        BARKOTA                                                                 0
# Tuition                GOLDEN FAITH ACADEMY                                                    0
#                        ICCT COLLEGES                                                           0
#                        NATIONAL TEACHERS COLLEGE                                               0
#                        PHINMA EDUCATION                                                        0
# Utility-Power          BATELEC2                                                                0
#                        BENECO                                                                  0
#                        Bills Collection - Angeles Electric                                     0
#                        CAGELCO1                                                                0
#                        CAPELCO                                                                 0
#                        CASURECO 4                                                              0
#                        CASURECO2                                                               0
#                        CASURECO3                                                               0
#                        CEBECO2                                                                 0
#                        CELCOR                                                                  0
#                        CENPELCO                                                                0
#                        CEPALCO                                                                 0
#                        COTELCO                                                                 0
#                        DASURECO                                                                0
#                        DAVAOLIGHT                                                              0
#                        DECORP                                                                  0
#                        FLECO                                                                   0
#                        ILECO1                                                                  0
#                        ILIGAN LIGHT                                                            0
#                        INEC                                                                    0
#                        ISECO                                                                   0
#                        LEYECO 2                                                                0
#                        LIMA ENERZONE                                                           0
#                        LUELCO                                                                  0
#                        MOELCI 2                                                                0
#                        MORESCO 1                                                               0
#                        NEECO1                                                                  0
#                        NEECO2 AREA1                                                            0
#                        NEECO2 AREA2                                                            0
#                        NORECO2                                                                 0
#                        NUVELCO                                                                 0
#                        OEDC                                                                    0
#                        PANELCO1                                                                0
#                        PANELCO3                                                                0
#                        PELCO 2                                                                 0
#                        PELCO1                                                                  0
#                        PENELCO                                                                 0
#                        PRESCO                                                                  0
#                        QUEZELCO1                                                               0
#                        SAJELCO                                                                 0
#                        SFELAPCO                                                                0
#                        SORECO2                                                                 0
#                        SubicEnerzone                                                           0
#                        TARELCO 1                                                               0
#                        TARELCO2                                                                0
#                        TARLAC ELECTRIC INC                                                     0
#                        ZAMECO1                                                                 0
#                        ZAMECO2                                                                 0
# Utility-Water          AQUA CENTRO                                                             0
#                        BAGUIO WATER                                                            0
#                        BOCAUE WATER DISTRICT                                                   0
#                        BPWATERWORKS                                                            0
#                        BULAKAN WATER                                                           0
#                        BUSTOS WATER DISTRICT                                                   0
#                        CALUMPIT WATER                                                          0
#                        CANDELARIA WATER DISTRICT                                               0
#                        CARCAR WATER DISTRICT                                                   0
#                        CDO WATER                                                               0
#                        CLARK WATER                                                             0
#                        COUNTRYWIDE WATER SERVICES                                              0
#                        Dagupan City Water District                                             0
#                        FIRST PEAK                                                              0
#                        GENSAN CITY WATER DISTRICT                                              0
#                        GOODHANDSWATER                                                          0
#                        HAPPYWELLMANAGEMENT                                                     0
#                        HIYAS WATER                                                             0
#                        LAGUNA WATER DISTRICT                                                   0
#                        MABALACAT WATER                                                         0
#                        MACTAN ROCK INDUSTRIES, INC.                                            0
#                        MANILAWATER PHILVENTURES                                                0
#                        MCWD (METRO CEBU)                                                       0
#                        METRO DUMAGUETE WATER                                                   0
#                        METRO LIPA WATER DISTRICT                                               0
#                        MIWD                                                                    0
#                        OBANDO WATER                                                            0
#                        PLARIDEL WATER                                                          0
#                        SUBICWATER                                                              0
#                        TANAY WATER DISTRICT                                                    0
#                        TERESA WATER DISTRICT                                                   0

# %%
# Create a Pandas Excel writer using ExcelWriter
excel_file = 'sector_analysis.xlsx'
with pd.ExcelWriter(excel_file) as writer:
    # Write each DataFrame to a separate sheet
    sector_result.to_excel(writer, sheet_name='Sector Result', index=False)
    sector_merchant_result.to_excel(writer, sheet_name='Sector Merchant Result', index=False)

print(f"Excel file '{excel_file}' has been created with two sheets.")
# Out:
# Excel file 'sector_analysis.xlsx' has been created with two sheets.
