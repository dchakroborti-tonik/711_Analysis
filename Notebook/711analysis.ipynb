# %% [markdown]
# # <div align="center" style="color: #ff5733;">7 11 Data Analysis</div>

# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.

# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
path = r'C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
# Example: pd.set_option('display.max_columns', None)

# %%
sq = """with mb as 
(select customer_id, right(new_mobile_number, 10) mobile from `risk_credit_mis.customer_contact_details`
union all 
select customer_id, right(old_mobile_number, 10) mobile from `risk_credit_mis.customer_contact_details` where old_mobile_number is not null
),
mb1 
as
(select distinct customer_id, mobile from mb),
mb2
as
(select *, row_number() over(partition by customer_id order by customer_id) custrank from mb1),
delqb as
(Select lmt.customerId, case when a1.obs_min_inst_def30 >= 3 then lmt.customerId end obsfstpd30 
, case when a1.min_inst_def30 in (1,2,3) then lmt.customerId end fstpd30dev
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data a1
left join `risk_credit_mis.loan_master_table` lmt on lmt.loanAccountNumber = a1.loanAccountNumber
),delqb1 
as
(select customerId, 
count(distinct case when obsfstpd30 is not null and fstpd30dev is not null then customerId end) fstpd30def,
count(distinct case when obsfstpd30 is not null then customerId else 0 end) obsfpd30
from delqb where obsfstpd30 is not null
group by 1
),
base as
(select * from 
`prj-prod-dataplatform.manual_source_extracts.partner_711_payment_transcation_backtest_20240125` a1
left join mb2 on cast(mb2.mobile as numeric) = cast(a1.mobile_num as numeric)
left join delqb1 on delqb1.customerId = cast(mb2.customer_id as numeric)
)
select * from base"""
df = client.query(sq).to_dataframe(progress_bar_type='tqdm')
# Out:
# Job ID 187453c2-b1c7-4e41-9864-b8db3830d98a successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
print(f"The shape of the dataset is:\t {df.shape}")
# Out:
# The shape of the dataset is:	 (1196007, 13)

# %%
df.columns
# Out:
# Index(['mobile_num', 'txn_id', 'amount', 'sector', 'merchant_name',
#        'txn_datetime', 'store_id', 'customer_id', 'mobile', 'custrank',
#        'customerId', 'fstpd30def', 'obsfpd30'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196007 entries, 0 to 1196006
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   mobile_num     1196007 non-null  Int64
#  1   txn_id         1196007 non-null  Int64
#  2   amount         1196007 non-null  float64
#  3   sector         1196007 non-null  object
#  4   merchant_name  1196007 non-null  object
#  5   txn_datetime   1196007 non-null  datetime64[us, UTC]
#  6   store_id       1196007 non-null  Int64
#  7   customer_id    1157189 non-null  Int64
#  8   mobile         1157189 non-null  object
#  9   custrank       1157189 non-null  Int64
#  10  customerId     518297 non-null   Int64
#  11  fstpd30def     518297 non-null   Int64
#  12  obsfpd30       518297 non-null   Int64
# dtypes: Int64(8), datetime64[us, UTC](1), float64(1), object(3)
# memory usage: 127.7+ MB

# %%
df['mobile_num'] = df['mobile_num'].astype(str)

# %%
df['sector'].value_counts()
# Out:
# sector
# EMI                       831125
# Loans                     149071
# Bank                       76768
# Prepaid Load               65593
# Postpaid Land Lines        12963
# Transpo or Toll            11468
# Government                 10260
# Utility-Water               8992
# Internet                    7733
# Remittance                  3897
# Utility-Power               3036
# Credit Card                 2908
# Cable TV                    2823
# Postpaid Mobile             2634
# E-Commerce                  1864
# E-Wallet                    1238
# Airlines                     983
# Gaming                       916
# Collections                  498
# Retailer Load                474
# Insurance                    353
# Tuition                      304
# Other Prepaid Services       106
# Name: count, dtype: int64

# %%
# Count matching lp_id with mobile
matching_count = df[df['mobile_num'].isin(df['mobile'])].shape[0]
# Count lp_id that are missing in mobile
missing_count = df[~df['mobile_num'].isin(df['mobile'])].shape[0]

# Total number of lp_id records
total_lp_id = df.shape[0]

# Calculate share of lp_id in mobile
share_in_mobile = (matching_count / total_lp_id) * 100

print(f"Number of lp_id matching with mobile: {matching_count}")
print(f"Number of lp_id missing in mobile: {missing_count}")
print(f"Share of lp_id in mobile: {share_in_mobile:.2f}%")
# Out:
# Number of lp_id matching with mobile: 1157189
# Number of lp_id missing in mobile: 38818
# Share of lp_id in mobile: 96.75%

# %%
df[df['mobile_num'].isin(df['mobile'])].to_csv("Matchingmobilenumberwithoutdatabase.csv", index = False)

# %%
df[~df['mobile_num'].isin(df['mobile'])].to_csv("Missingmobilenumberfromourdatabasewhenmatchingwith711data.csv", index = False)

# %%
# df[~df['mobile_num'].isin(df['mobile'])]

# %%
# Get unique lp_id and mobile values
unique_lp_ids = df['mobile_num'].unique()
unique_mobiles = df['mobile'].unique()

# Count how many unique lp_id values are in unique mobiles
matching_count = sum(lp_id in unique_mobiles for lp_id in unique_lp_ids)

# Total number of unique lp_id records
total_unique_lp_id = len(unique_lp_ids)

# Calculate share of unique lp_id in unique mobiles
share_in_mobile = (matching_count / total_unique_lp_id) * 100

print(f"Number of unique lp_id matching with unique mobile: {matching_count}")
print(f"Total number of unique lp_id: {total_unique_lp_id}")
print(f"Share of unique lp_id in unique mobile: {share_in_mobile:.2f}%")
# Out:
# Number of unique lp_id matching with unique mobile: 58521
# Total number of unique lp_id: 60686
# Share of unique lp_id in unique mobile: 96.43%

# %%
df.columns
# Out:
# Index(['mobile_num', 'txn_id', 'amount', 'sector', 'merchant_name',
#        'txn_datetime', 'store_id', 'customer_id', 'mobile', 'custrank',
#        'customerId', 'fstpd30def', 'obsfpd30'],
#       dtype='object')

# %%
# Calculate count of unique customers per sector
unique_customers_count = df.groupby('sector')['customer_id'].nunique()
unique_711mobile_count = df.groupby('sector')['mobile_num'].nunique()
unique_obsfstpd30_customer_count = df.groupby('sector')['customerId'].nunique()
unique_fstpd30_customer_count = df[df['fstpd30def']==1].groupby('sector')['customerId'].nunique()

# Combine results into a DataFrame
result_df = pd.DataFrame({
    'Sector': sector_default_rate.index,
    'Unique Customers Count': unique_customers_count,
    'unique 711mobile count': unique_711mobile_count,
    'Observed fstpd30 customer count': unique_obsfstpd30_customer_count,
    'unique_fstpd30_customer_count': unique_fstpd30_customer_count,
})

result_df['Default Rate (%)'] = round(result_df['unique_fstpd30_customer_count']/result_df['Observed fstpd30 customer count']*100, 3)

# Sort by Default Rate in descending order
result_df_sorted = result_df.sort_values(by='Default Rate (%)', ascending=False)

print("Sector-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):")
sector_result = result_df_sorted.copy()
sector_result
# Out:
# Sector-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):
#                                         Sector  Unique Customers Count  \
# sector
# Other Prepaid Services  Other Prepaid Services                      49
# Tuition                                Tuition                     119
# Prepaid Load                      Prepaid Load                   15558
# Utility-Power                    Utility-Power                     889
# Bank                                      Bank                    4041
# Gaming                                  Gaming                      98
# Cable TV                              Cable TV                     771
# Postpaid Land Lines        Postpaid Land Lines                    3273
# E-Wallet                              E-Wallet                     382
# Loans                                    Loans                   15353
# Remittance                          Remittance                    1234
# EMI                                        EMI                   57735
# Internet                              Internet                    2147
# Government                          Government                    6310
# Transpo or Toll                Transpo or Toll                    1783
# Utility-Water                    Utility-Water                    2683
# E-Commerce                          E-Commerce                     768
# Postpaid Mobile                Postpaid Mobile                     665
# Airlines                              Airlines                     625
# Insurance                            Insurance                      67
# Collections                        Collections                      82
# Credit Card                        Credit Card                     657
# Retailer Load                    Retailer Load                      43
#
#                         unique 711mobile count  \
# sector
# Other Prepaid Services                      50
# Tuition                                    121
# Prepaid Load                             16077
# Utility-Power                              923
# Bank                                      4234
# Gaming                                     100
# Cable TV                                   798
# Postpaid Land Lines                       3373
# E-Wallet                                   393
# Loans                                    15997
# Remittance                                1280
# EMI                                      59864
# Internet                                  2218
# Government                                6530
# Transpo or Toll                           1832
# Utility-Water                             2790
# E-Commerce                                 808
# Postpaid Mobile                            694
# Airlines                                   656
# Insurance                                   71
# Collections                                 84
# Credit Card                                681
# Retailer Load                               44
#
#                         Observed fstpd30 customer count  \
# sector
# Other Prepaid Services                               27
# Tuition                                              57
# Prepaid Load                                       7179
# Utility-Power                                       377
# Bank                                               2044
# Gaming                                               44
# Cable TV                                            413
# Postpaid Land Lines                                1628
# E-Wallet                                            154
# Loans                                              7865
# Remittance                                          604
# EMI                                               28179
# Internet                                           1110
# Government                                         3096
# Transpo or Toll                                     947
# Utility-Water                                      1460
# E-Commerce                                          399
# Postpaid Mobile                                     382
# Airlines                                            336
# Insurance                                            40
# Collections                                          33
# Credit Card                                         381
# Retailer Load                                        25
#
#                         unique_fstpd30_customer_count  Default Rate (%)
# sector
# Other Prepaid Services                             13            48.148
# Tuition                                            23            40.351
# Prepaid Load                                     2686            37.415
# Utility-Power                                     135            35.809
# Bank                                              700            34.247
# Gaming                                             15            34.091
# Cable TV                                          139            33.656
# Postpaid Land Lines                               538            33.047
# E-Wallet                                           50            32.468
# Loans                                            2500            31.786
# Remittance                                        190            31.457
# EMI                                              8807            31.254
# Internet                                          345            31.081
# Government                                        945            30.523
# Transpo or Toll                                   284            29.989
# Utility-Water                                     423            28.973
# E-Commerce                                        114            28.571
# Postpaid Mobile                                   103            26.963
# Airlines                                           87            25.893
# Insurance                                          10            25.000
# Collections                                         8            24.242
# Credit Card                                        88            23.097
# Retailer Load                                       4            16.000

# %%
result_df.head()
# Out:
#                   Sector  Unique Customers Count  unique 711mobile count  \
# sector
# Airlines        Airlines                     625                     656
# Bank                Bank                    4041                    4234
# Cable TV        Cable TV                     771                     798
# Collections  Collections                      82                      84
# Credit Card  Credit Card                     657                     681
#
#              Observed fstpd30 customer count  unique_fstpd30_customer_count  \
# sector
# Airlines                                 336                             87
# Bank                                    2044                            700
# Cable TV                                 413                            139
# Collections                               33                              8
# Credit Card                              381                             88
#
#              Default Rate (%)
# sector
# Airlines               25.893
# Bank                   34.247
# Cable TV               33.656
# Collections            24.242
# Credit Card            23.097

# %%
# Assuming you have already defined unique_customers_count, unique_711mobile_count,
# unique_obsfstpd30_customer_count, and unique_fstpd30_customer_count

# Combine results into a DataFrame
result_df = pd.DataFrame({
    'Sector': unique_customers_count.index.get_level_values(0),
    'Merchant': unique_customers_count.index.get_level_values(1),
    'Unique Customers Count': unique_customers_count,
    'unique 711mobile count': unique_711mobile_count,
    'Observed fstpd30 customer count': unique_obsfstpd30_customer_count,
    'fstpd30 Customer Count': unique_fstpd30_customer_count,
})

# Calculate default rate
result_df['sector_merchant_default_rate'] = round(result_df['fstpd30 Customer Count'] / result_df['Observed fstpd30 customer count'] * 100, 3)

# Sort by Default Rate in descending order
result_df_sorted = result_df.sort_values(by='sector_merchant_default_rate', ascending=False)

pd.set_option('display.max_rows', None)
print("Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):")
result_df_sorted
# Out:
# Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):
#                                                                                  Sector  \
# sector                 merchant_name
# Loans                  SURECYCLE FINANCE                                          Loans
# Airlines               PAL (OTP Booking)                                       Airlines
# Credit Card            CHINABANK CREDITCARD                                 Credit Card
# Utility-Water          CARCAR WATER DISTRICT                              Utility-Water
# Collections            VIVAMAX INC                                          Collections
# Utility-Water          METRO LIPA WATER DISTRICT                          Utility-Water
# Prepaid Load           GLOBE GO400                                         Prepaid Load
# Collections            JOHNDORF                                             Collections
# Loans                  U PESO LENDING                                             Loans
#                        JUAN CASH                                                  Loans
#                        INSULAR SAVERS                                             Loans
#                        FUNDLINE                                                   Loans
# Gaming                 GAMECLUB 20                                               Gaming
# Cable TV               JMD CABLE NETWORK                                       Cable TV
# Prepaid Load           TM SURF4ALL249TM                                    Prepaid Load
# Gaming                 GAMECLUB 300                                              Gaming
#                        GAMECLUB 500                                              Gaming
# Loans                  CEBU CFI                                                   Loans
#                        CARD SME BANK                                              Loans
#                        BAGUIO BENGUET COMMUNITY CREDIT COOP                       Loans
# Utility-Power          INEC                                               Utility-Power
# Insurance              DIALEX                                                 Insurance
# Utility-Power          NEECO2 AREA1                                       Utility-Power
# Postpaid Land Lines    BAYANTEL                                     Postpaid Land Lines
# Loans                  BANCO ALABANG                                              Loans
# Utility-Power          NORECO2                                            Utility-Power
# Utility-Water          HAPPYWELLMANAGEMENT                                Utility-Water
# Loans                  SECOND PAY                                                 Loans
# Other Prepaid Services FAMLOAD VIDEO 199                         Other Prepaid Services
# Utility-Water          CDO WATER                                          Utility-Water
#                        OBANDO WATER                                       Utility-Water
# Utility-Power          PENELCO                                            Utility-Power
#                        MECO                                               Utility-Power
#                        CEPALCO                                            Utility-Power
# Utility-Water          MCWD (METRO CEBU)                                  Utility-Water
# Loans                  MOTORSTAR (Probikes)                                       Loans
#                        Motorcentral                                               Loans
# Utility-Power          TARELCO2                                           Utility-Power
# Prepaid Load           Giga Video+ 149                                     Prepaid Load
# Utility-Power          Bills Collection - Angeles Electric                Utility-Power
# Prepaid Load           SUNXPRESSLOAD 30                                    Prepaid Load
# Loans                  FILPROGRESS CREDIT                                         Loans
#                        CARD MRI RIZAL BANK                                        Loans
#                        CARD BANK INC                                              Loans
# Utility-Power          FLECO                                              Utility-Power
#                        ILIGAN LIGHT                                       Utility-Power
# Utility-Water          HIYAS WATER                                        Utility-Water
# Prepaid Load           SUN XPRESSLOAD 25                                   Prepaid Load
#                        SUNXPRESSLOAD 50                                    Prepaid Load
#                        SMART GIGA VIDEO 299                                Prepaid Load
# Loans                  NOVADECI                                                   Loans
# Utility-Water          CALUMPIT WATER                                     Utility-Water
# Loans                  SOUTH ASIALINK                                             Loans
# Utility-Water          Dagupan City Water District                        Utility-Water
# Other Prepaid Services CIGNAL 300                                Other Prepaid Services
#                        CIGNAL 600                                Other Prepaid Services
# Prepaid Load           DITO E-LOAD 300                                     Prepaid Load
# Other Prepaid Services FAMLOAD VIDEO 599                         Other Prepaid Services
#                        NETFLIX 550                               Other Prepaid Services
# Insurance              COCOLIFE                                               Insurance
# Utility-Power          OEDC                                               Utility-Power
# Gaming                 GARENA 500                                                Gaming
# Government             MULTIPAY (MANILA)                                     Government
# Utility-Water          STALUCIA                                           Utility-Water
# EMI                    TAGCASH                                                      EMI
# Cable TV               DASCA CABLE SERVICES INC                                Cable TV
# Gaming                 GARENA 300                                                Gaming
# Prepaid Load           TM SURF4ALL99TM                                     Prepaid Load
#                        GLOBE AMAX GO UNLI 30                               Prepaid Load
# Tuition                DRAGON SCHOOLS                                           Tuition
# Prepaid Load           TM ALL IN SURF 20 FB                                Prepaid Load
# E-Wallet               MAXIM                                                   E-Wallet
# Prepaid Load           GLOBE 50                                            Prepaid Load
# Airlines               PHILIPPINEAIRLINES                                      Airlines
# Prepaid Load           SUN TEXT UNLIMITED 50                               Prepaid Load
#                        GLOBE 300                                           Prepaid Load
#                        GLOBE SURF4ALL99GP                                  Prepaid Load
#                        GLOBE GO+129                                        Prepaid Load
# Utility-Power          ILECO1                                             Utility-Power
# E-Wallet               E-Money - EON                                           E-Wallet
# Loans                  AGRIBANK                                                   Loans
# Prepaid Load           GRAMEEN PILIPINAS MICROFINANCE                      Prepaid Load
# Gaming                 DRAGONGAMES                                               Gaming
# Utility-Power          SFELAPCO                                           Utility-Power
# Prepaid Load           TM EASYSURF 50                                      Prepaid Load
# Utility-Water          BPWATERWORKS                                       Utility-Water
# Prepaid Load           GLOBE 30                                            Prepaid Load
#                        SUNXPRESSLOAD 300                                   Prepaid Load
# Loans                  ORICO                                                      Loans
# Prepaid Load           ALL OUT SURF 30                                     Prepaid Load
# Loans                  MALAYAN BANK                                               Loans
# Prepaid Load           GIGA SURF 99                                        Prepaid Load
#                        GLOBE GOSURF 50                                     Prepaid Load
# Loans                  SKYPAY                                                     Loans
# Gaming                 GAMETIME                                                  Gaming
# Prepaid Load           GLOBE GO+149                                        Prepaid Load
#                        TM EZ70                                             Prepaid Load
#                        TNT Surf Saya 99                                    Prepaid Load
#                        SMART GIGA STORIES 99                               Prepaid Load
# Utility-Power          PELCO 2                                            Utility-Power
# Loans                  Plentina                                                   Loans
# Utility-Power          VECO                                               Utility-Power
# Prepaid Load           SMART GIGA STORIES 299                              Prepaid Load
#                        GLOBE SURF4ALL249GP                                 Prepaid Load
# Other Prepaid Services GLOBE HOMESURF 199                        Other Prepaid Services
# Loans                  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)                   Loans
#                        CEPAT                                                      Loans
# Utility-Power          PRESCO                                             Utility-Power
# Tuition                PHINMA EDUCATION                                         Tuition
# Loans                  RFC LOAN                                                   Loans
# Prepaid Load           GLOBE GO50                                          Prepaid Load
# E-Commerce             DRAGON PAY                                            E-Commerce
# Utility-Water          LAGUNA WATER                                       Utility-Water
# Prepaid Load           GLOBE GOSAKTO 140                                   Prepaid Load
#                        GLOBE GO+99                                         Prepaid Load
#                        TM ALL IN SURF 30                                   Prepaid Load
#                        GIGA SURF 50                                        Prepaid Load
#                        GLOBE GO120                                         Prepaid Load
# Loans                  CASHBEE                                                    Loans
# Prepaid Load           SMART REGULAR 30                                    Prepaid Load
# Loans                  FastLoan                                                   Loans
# Cable TV               Bills Payment - Royal Cable                             Cable TV
# Prepaid Load           GLOBE GO140                                         Prepaid Load
# Tuition                NATIONAL TEACHERS COLLEGE                                Tuition
# Collections            CBN ASIA                                             Collections
# Prepaid Load           GLOBE Autoload                                      Prepaid Load
# EMI                    Paymaya                                                      EMI
# Cable TV               SKYLINE CATV INDUSTRIES INC                             Cable TV
# Utility-Water          SUBICWATER                                         Utility-Water
# Prepaid Load           SMART REGULAR 115                                   Prepaid Load
# Bank                   UNIONBANK                                                   Bank
# Prepaid Load           GLOBE GOSAKTO 120                                   Prepaid Load
#                        GLOBE GOSAKTO 90                                    Prepaid Load
# Loans                  GLOBAL DOMINION                                            Loans
# Prepaid Load           GLOBE GO90                                          Prepaid Load
# Cable TV               SKYCABLE                                                Cable TV
#                        PLANET CABLE / MEDIASCAPE-CIGNAL                        Cable TV
# Loans                  SUMISHO                                                    Loans
# E-Commerce             AGODA                                                 E-Commerce
# Loans                  DRAGON LOANS                                               Loans
# Prepaid Load           SMART REGULAR 60                                    Prepaid Load
# Government             NBI                                                   Government
# Loans                  ASIALINK                                                   Loans
# Postpaid Land Lines    GLOBELINES                                   Postpaid Land Lines
# Loans                  PAYSO                                                      Loans
# Other Prepaid Services FAMLOAD VIDEO 999                         Other Prepaid Services
# Cable TV               ASIAN VISION CABLE                                      Cable TV
# Prepaid Load           GLOBE GO+250                                        Prepaid Load
# Utility-Power          LUELCO                                             Utility-Power
# Utility-Water          MIWD                                               Utility-Water
# Cable TV               KABAYAN CABLE CORP                                      Cable TV
# Prepaid Load           SUNXPRESSLOAD 75                                    Prepaid Load
# Utility-Power          DAVAOLIGHT                                         Utility-Power
#                        DASURECO                                           Utility-Power
# Loans                  COUNTRY FUNDERS                                            Loans
# Utility-Power          ZAMECO1                                            Utility-Power
# Loans                  CVM FINANCE                                                Loans
# Utility-Water          MANILAWATER PHILVENTURES                           Utility-Water
# Postpaid Land Lines    PLDT                                         Postpaid Land Lines
# E-Wallet               PISOPAY                                                 E-Wallet
# Prepaid Load           SMART REGULAR 500                                   Prepaid Load
#                        SUNXPRESSLOAD 100                                   Prepaid Load
#                        DITO E-LOAD 200                                     Prepaid Load
#                        DITO E-LOAD 100                                     Prepaid Load
#                        GLOBE 100                                           Prepaid Load
# EMI                    Coins.ph                                                     EMI
# Loans                  FLEXI FINANCE                                              Loans
# Credit Card            ROBINSONBANK CREDITCARD                              Credit Card
# Government             MARINA                                                Government
# Loans                  ACOM                                                       Loans
# Remittance             Palawan Padala                                        Remittance
# Loans                  PAYEXPRESS LOAN                                            Loans
# EMI                    GCash                                                        EMI
# Internet               CONVERGEICT                                             Internet
# Prepaid Load           UNLICALL 15                                         Prepaid Load
# EMI                    HELLO MONEY                                                  EMI
# Prepaid Load           SMART REGULAR 300                                   Prepaid Load
#                        TNT Giga Video 50                                   Prepaid Load
# Utility-Water          MAYNILAD                                           Utility-Water
# Gaming                 METROTURF                                                 Gaming
# E-Commerce             NETFLIX DragonPay                                     E-Commerce
# Government             NSOHELPLINE.COM                                       Government
# Transpo or Toll        EASYTRIP                                         Transpo or Toll
# Utility-Water          PRIMEWATER                                         Utility-Water
#                        MANILAWATER                                        Utility-Water
# Prepaid Load           GLOBE 70                                            Prepaid Load
#                        TNT Giga Video 99                                   Prepaid Load
# Utility-Power          CEBECO2                                            Utility-Power
# Government             BUREAU OF QUARANTINE                                  Government
# Collections            PAYEXPRESS TICKETS                                   Collections
# Utility-Power          BATELEC1                                           Utility-Power
# Prepaid Load           TOUCHMOBILE 50                                      Prepaid Load
#                        SUN TU200 200                                       Prepaid Load
# Loans                  NWOW                                                       Loans
# Transpo or Toll        RFID                                             Transpo or Toll
# Loans                  CHINATRUST                                                 Loans
# Bank                   CIMB                                                        Bank
# Postpaid Mobile        GHPHONE                                          Postpaid Mobile
# Utility-Power          BATELEC2                                           Utility-Power
# Loans                  MITSUKOSHI                                                 Loans
#                        TALA                                                       Loans
# Government             DFA                                                   Government
# Loans                  LENDPINOY                                                  Loans
# Cable TV               CABLELINK                                               Cable TV
# Loans                  HOME CREDIT                                                Loans
# Government             MYEG PH                                               Government
# Utility-Water          GOODHANDSWATER                                     Utility-Water
# Transpo or Toll        BARKOTA                                          Transpo or Toll
# Credit Card            BANK OF COMMERCE CREDIT CARD                         Credit Card
# Loans                  UNIONBANK QUICKLOANS                                       Loans
# Postpaid Mobile        SMART                                            Postpaid Mobile
# Gaming                 STEAM 299                                                 Gaming
# Utility-Water          METRO DUMAGUETE WATER                              Utility-Water
# Prepaid Load           GLOBE GO+400                                        Prepaid Load
# Utility-Water          WATERS PH                                          Utility-Water
#                        FIRST PEAK                                         Utility-Water
# Gaming                 STEAM 120                                                 Gaming
# Utility-Power          DECORP                                             Utility-Power
# Utility-Water          LAGUNA WATER DISTRICT                              Utility-Water
# Utility-Power          CAPELCO                                            Utility-Power
# Prepaid Load           GLOBE Autoload 350                                  Prepaid Load
# Airlines               CEBUPACIFIC                                             Airlines
# EMI                    Lazada                                                       EMI
# Loans                  CASHALO                                                    Loans
# Utility-Water          SB FINANCE                                         Utility-Water
# E-Wallet               ABRA                                                    E-Wallet
# Insurance              AXAPHIL                                                Insurance
# Credit Card            BPI CREDITCARD                                       Credit Card
# Loans                  PSBANK LOAN                                                Loans
# Bank                   DISKARTECH 5001 to 15000                                    Bank
# Cable TV               BINANGONAN CABLE TV CORP                                Cable TV
# Retailer Load          SMART RETAILER 500                                 Retailer Load
# Tuition                ICCT COLLEGES                                            Tuition
# E-Commerce             SHOPEE                                                E-Commerce
# Loans                  AeonCredit                                                 Loans
# EMI                    SHOPEEPAY (DRAGONPAY)                                        EMI
# Credit Card            SBC MASTERCARD PESO                                  Credit Card
# Loans                  ZURICH                                                     Loans
# Utility-Water          TAGUM WATER                                        Utility-Water
# Bank                   DISKARTECH 1 to 5000                                        Bank
# Prepaid Load           TNT GIGA VIDEO 299                                  Prepaid Load
# Retailer Load          GLOBE RETAILER 500                                 Retailer Load
# Collections            PERSONAL COLLECTION                                  Collections
# Utility-Water          SOUTH LUZON WATER                                  Utility-Water
# Bank                   DISKARTECH 15001 to 25000                                   Bank
# Credit Card            METROBANK                                            Credit Card
# Utility-Power          BENECO                                             Utility-Power
# Prepaid Load           SMART GIGA GAMES 99                                 Prepaid Load
# Postpaid Mobile        SUNCELLULAR                                      Postpaid Mobile
# Utility-Water          ePRIME                                             Utility-Water
# Bank                   MAYBANK                                                     Bank
# Utility-Water          METRO ROXAS WATER DISTRICT                         Utility-Water
#                        COUNTRYWIDE WATER SERVICES                         Utility-Water
# Utility-Power          PELCO 3                                            Utility-Power
# Cable TV               PLANET CABLE                                            Cable TV
# Prepaid Load           SUNXPRESSLOAD 150                                   Prepaid Load
# Utility-Power          CENPELCO                                           Utility-Power
# Prepaid Load           GLOBE 500                                           Prepaid Load
# Cable TV               BICOL ONE BROADBAND SERVICE                             Cable TV
#                        CENTRALLUZONCABLETV                                     Cable TV
#                        FIL PRODUCTS                                            Cable TV
#                        GALAXY CABLE                                            Cable TV
#                        PARASAT                                                 Cable TV
#                        SOUTH LUZON CABLE                                       Cable TV
#                        USATV                                                   Cable TV
# Collections            ANJELMAN                                             Collections
#                        APMC                                                 Collections
#                        Bills Payment - Honeycomb                            Collections
#                        CAD REALTY                                           Collections
#                        DINGDONG                                             Collections
#                        Donation Key (GOLDEN HAVEN)                          Collections
#                        GREENWEATH DEVELOPMENT CORP.                         Collections
#                        JACQMAN                                              Collections
#                        LOADMANNA, INC.                                      Collections
#                        MASTERMAN                                            Collections
#                        NETPLAY INC                                          Collections
#                        PAYCOOLS                                             Collections
#                        RAYMOND REALTY                                       Collections
#                        RS MANAGEMENT                                        Collections
#                        SMARTMAN                                             Collections
#                        VTEC                                                 Collections
# Credit Card            AUB CREDITCARDS                                      Credit Card
# E-Wallet               FORTUNE PAY                                             E-Wallet
#                        GETGO                                                   E-Wallet
#                        HOMECREDIT PAY                                          E-Wallet
#                        MAGICPAY                                                E-Wallet
#                        NETBANK DEPOSIT                                         E-Wallet
#                        YAZZ                                                    E-Wallet
# EMI                    ALLEASY                                                      EMI
#                        GRAB                                                         EMI
#                        RCBC myWallet                                                EMI
# Gaming                 GAMECLUB 100                                              Gaming
#                        GAMECLUB 50                                               Gaming
#                        GARENA 100                                                Gaming
#                        GARENA 1000                                               Gaming
#                        GARENA 200                                                Gaming
#                        GARENA 50                                                 Gaming
#                        STEAM 2640                                                Gaming
#                        STEAM 599                                                 Gaming
#                        STEAM 60                                                  Gaming
#                        STEAM 960                                                 Gaming
#                        UniPin Voucher 100                                        Gaming
#                        UniPin Voucher 300                                        Gaming
# Government             BSP                                                   Government
#                        MARINA (PISOPAY)                                      Government
#                        SOCIAL HOUSING FINANCE CORPORATION                    Government
# Insurance              CONNEXT MARKETING                                      Insurance
#                        INSULAR LIFE                                           Insurance
#                        PARAMOUNT                                              Insurance
# Internet               BICORE                                                  Internet
#                        WOOFY                                                   Internet
# Loans                  CARD INC                                                   Loans
#                        CHAILEASE BERJAYA                                          Loans
#                        CTFSI                                                      Loans
#                        DS FINANCE                                                 Loans
#                        ENCORE LEASING AND FINANCE CORP                            Loans
#                        FINASWIDE                                                  Loans
#                        FIRST STANDARD                                             Loans
#                        FORBES LENDING                                             Loans
#                        GLOBAL SME LOANS                                           Loans
#                        GRAMEEN PILIPINAS MICROFINANCE                             Loans
#                        LOAN STAR                                                  Loans
#                        MEGASAVER                                                  Loans
#                        OLM LENDING                                                Loans
#                        PERAJET                                                    Loans
#                        SIMBAYANAN COOP                                            Loans
#                        STO NINO DE CEBU FINANCE                                   Loans
# Other Prepaid Services CIGNAL 1000                               Other Prepaid Services
#                        CIGNAL 450                                Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 199                    Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 999                    Other Prepaid Services
#                        GLOBE HOMEWATCH 199                       Other Prepaid Services
#                        NETFLIX 1000                              Other Prepaid Services
#                        NETFLIX 459                               Other Prepaid Services
# Prepaid Load           CHERRY LOAD 30                                      Prepaid Load
#                        CHERRY LOAD 50                                      Prepaid Load
#                        DITO E-LOAD 500                                     Prepaid Load
#                        SUN TEXT UNLIMITED 150                              Prepaid Load
#                        TOUCHMOBILE 30                                      Prepaid Load
#                        TOUCHMOBILE 70                                      Prepaid Load
# Retailer Load          GLOBE RETAILER 1000                                Retailer Load
#                        GLOBE RETAILER 1500                                Retailer Load
#                        GLOBE RETAILER 2000                                Retailer Load
#                        SMART RETAILER 1000                                Retailer Load
#                        SMART RETAILER 1500                                Retailer Load
#                        SMART RETAILER 2000                                Retailer Load
#                        SMART RETAILER 2500                                Retailer Load
# Tuition                GOLDEN FAITH ACADEMY                                     Tuition
# Utility-Power          CAGELCO1                                           Utility-Power
#                        CASURECO 4                                         Utility-Power
#                        CASURECO2                                          Utility-Power
#                        CASURECO3                                          Utility-Power
#                        CEBECO 3                                           Utility-Power
#                        CELCOR                                             Utility-Power
#                        COTELCO                                            Utility-Power
#                        ISECO                                              Utility-Power
#                        LEYECO 2                                           Utility-Power
#                        LIMA ENERZONE                                      Utility-Power
#                        MOELCI 2                                           Utility-Power
#                        MORESCO 1                                          Utility-Power
#                        NEECO1                                             Utility-Power
#                        NEECO2 AREA2                                       Utility-Power
#                        NUVELCO                                            Utility-Power
#                        PANELCO1                                           Utility-Power
#                        PANELCO3                                           Utility-Power
#                        PELCO1                                             Utility-Power
#                        QUEZELCO1                                          Utility-Power
#                        SAJELCO                                            Utility-Power
#                        SORECO2                                            Utility-Power
#                        SubicEnerzone                                      Utility-Power
#                        TARELCO 1                                          Utility-Power
#                        TARLAC ELECTRIC INC                                Utility-Power
#                        ZAMECO2                                            Utility-Power
# Utility-Water          AQUA CENTRO                                        Utility-Water
#                        BAGUIO WATER                                       Utility-Water
#                        BOCAUE WATER DISTRICT                              Utility-Water
#                        BULACAN WATER                                      Utility-Water
#                        BULAKAN WATER                                      Utility-Water
#                        BUSTOS WATER DISTRICT                              Utility-Water
#                        CANDELARIA WATER DISTRICT                          Utility-Water
#                        CLARK WATER                                        Utility-Water
#                        GENSAN CITY WATER DISTRICT                         Utility-Water
#                        MABALACAT WATER                                    Utility-Water
#                        MACTAN ROCK INDUSTRIES, INC.                       Utility-Water
#                        PLARIDEL WATER                                     Utility-Water
#                        TANAY WATER DISTRICT                               Utility-Water
#                        TERESA WATER DISTRICT                              Utility-Water
#
#                                                                                                  Merchant  \
# sector                 merchant_name
# Loans                  SURECYCLE FINANCE                                                SURECYCLE FINANCE
# Airlines               PAL (OTP Booking)                                                PAL (OTP Booking)
# Credit Card            CHINABANK CREDITCARD                                          CHINABANK CREDITCARD
# Utility-Water          CARCAR WATER DISTRICT                                        CARCAR WATER DISTRICT
# Collections            VIVAMAX INC                                                            VIVAMAX INC
# Utility-Water          METRO LIPA WATER DISTRICT                                METRO LIPA WATER DISTRICT
# Prepaid Load           GLOBE GO400                                                            GLOBE GO400
# Collections            JOHNDORF                                                                  JOHNDORF
# Loans                  U PESO LENDING                                                      U PESO LENDING
#                        JUAN CASH                                                                JUAN CASH
#                        INSULAR SAVERS                                                      INSULAR SAVERS
#                        FUNDLINE                                                                  FUNDLINE
# Gaming                 GAMECLUB 20                                                            GAMECLUB 20
# Cable TV               JMD CABLE NETWORK                                                JMD CABLE NETWORK
# Prepaid Load           TM SURF4ALL249TM                                                  TM SURF4ALL249TM
# Gaming                 GAMECLUB 300                                                          GAMECLUB 300
#                        GAMECLUB 500                                                          GAMECLUB 500
# Loans                  CEBU CFI                                                                  CEBU CFI
#                        CARD SME BANK                                                        CARD SME BANK
#                        BAGUIO BENGUET COMMUNITY CREDIT COOP          BAGUIO BENGUET COMMUNITY CREDIT COOP
# Utility-Power          INEC                                                                          INEC
# Insurance              DIALEX                                                                      DIALEX
# Utility-Power          NEECO2 AREA1                                                          NEECO2 AREA1
# Postpaid Land Lines    BAYANTEL                                                                  BAYANTEL
# Loans                  BANCO ALABANG                                                        BANCO ALABANG
# Utility-Power          NORECO2                                                                    NORECO2
# Utility-Water          HAPPYWELLMANAGEMENT                                            HAPPYWELLMANAGEMENT
# Loans                  SECOND PAY                                                              SECOND PAY
# Other Prepaid Services FAMLOAD VIDEO 199                                                FAMLOAD VIDEO 199
# Utility-Water          CDO WATER                                                                CDO WATER
#                        OBANDO WATER                                                          OBANDO WATER
# Utility-Power          PENELCO                                                                    PENELCO
#                        MECO                                                                          MECO
#                        CEPALCO                                                                    CEPALCO
# Utility-Water          MCWD (METRO CEBU)                                                MCWD (METRO CEBU)
# Loans                  MOTORSTAR (Probikes)                                          MOTORSTAR (Probikes)
#                        Motorcentral                                                          Motorcentral
# Utility-Power          TARELCO2                                                                  TARELCO2
# Prepaid Load           Giga Video+ 149                                                    Giga Video+ 149
# Utility-Power          Bills Collection - Angeles Electric            Bills Collection - Angeles Electric
# Prepaid Load           SUNXPRESSLOAD 30                                                  SUNXPRESSLOAD 30
# Loans                  FILPROGRESS CREDIT                                              FILPROGRESS CREDIT
#                        CARD MRI RIZAL BANK                                            CARD MRI RIZAL BANK
#                        CARD BANK INC                                                        CARD BANK INC
# Utility-Power          FLECO                                                                        FLECO
#                        ILIGAN LIGHT                                                          ILIGAN LIGHT
# Utility-Water          HIYAS WATER                                                            HIYAS WATER
# Prepaid Load           SUN XPRESSLOAD 25                                                SUN XPRESSLOAD 25
#                        SUNXPRESSLOAD 50                                                  SUNXPRESSLOAD 50
#                        SMART GIGA VIDEO 299                                          SMART GIGA VIDEO 299
# Loans                  NOVADECI                                                                  NOVADECI
# Utility-Water          CALUMPIT WATER                                                      CALUMPIT WATER
# Loans                  SOUTH ASIALINK                                                      SOUTH ASIALINK
# Utility-Water          Dagupan City Water District                            Dagupan City Water District
# Other Prepaid Services CIGNAL 300                                                              CIGNAL 300
#                        CIGNAL 600                                                              CIGNAL 600
# Prepaid Load           DITO E-LOAD 300                                                    DITO E-LOAD 300
# Other Prepaid Services FAMLOAD VIDEO 599                                                FAMLOAD VIDEO 599
#                        NETFLIX 550                                                            NETFLIX 550
# Insurance              COCOLIFE                                                                  COCOLIFE
# Utility-Power          OEDC                                                                          OEDC
# Gaming                 GARENA 500                                                              GARENA 500
# Government             MULTIPAY (MANILA)                                                MULTIPAY (MANILA)
# Utility-Water          STALUCIA                                                                  STALUCIA
# EMI                    TAGCASH                                                                    TAGCASH
# Cable TV               DASCA CABLE SERVICES INC                                  DASCA CABLE SERVICES INC
# Gaming                 GARENA 300                                                              GARENA 300
# Prepaid Load           TM SURF4ALL99TM                                                    TM SURF4ALL99TM
#                        GLOBE AMAX GO UNLI 30                                        GLOBE AMAX GO UNLI 30
# Tuition                DRAGON SCHOOLS                                                      DRAGON SCHOOLS
# Prepaid Load           TM ALL IN SURF 20 FB                                          TM ALL IN SURF 20 FB
# E-Wallet               MAXIM                                                                        MAXIM
# Prepaid Load           GLOBE 50                                                                  GLOBE 50
# Airlines               PHILIPPINEAIRLINES                                              PHILIPPINEAIRLINES
# Prepaid Load           SUN TEXT UNLIMITED 50                                        SUN TEXT UNLIMITED 50
#                        GLOBE 300                                                                GLOBE 300
#                        GLOBE SURF4ALL99GP                                              GLOBE SURF4ALL99GP
#                        GLOBE GO+129                                                          GLOBE GO+129
# Utility-Power          ILECO1                                                                      ILECO1
# E-Wallet               E-Money - EON                                                        E-Money - EON
# Loans                  AGRIBANK                                                                  AGRIBANK
# Prepaid Load           GRAMEEN PILIPINAS MICROFINANCE                      GRAMEEN PILIPINAS MICROFINANCE
# Gaming                 DRAGONGAMES                                                            DRAGONGAMES
# Utility-Power          SFELAPCO                                                                  SFELAPCO
# Prepaid Load           TM EASYSURF 50                                                      TM EASYSURF 50
# Utility-Water          BPWATERWORKS                                                          BPWATERWORKS
# Prepaid Load           GLOBE 30                                                                  GLOBE 30
#                        SUNXPRESSLOAD 300                                                SUNXPRESSLOAD 300
# Loans                  ORICO                                                                        ORICO
# Prepaid Load           ALL OUT SURF 30                                                    ALL OUT SURF 30
# Loans                  MALAYAN BANK                                                          MALAYAN BANK
# Prepaid Load           GIGA SURF 99                                                          GIGA SURF 99
#                        GLOBE GOSURF 50                                                    GLOBE GOSURF 50
# Loans                  SKYPAY                                                                      SKYPAY
# Gaming                 GAMETIME                                                                  GAMETIME
# Prepaid Load           GLOBE GO+149                                                          GLOBE GO+149
#                        TM EZ70                                                                    TM EZ70
#                        TNT Surf Saya 99                                                  TNT Surf Saya 99
#                        SMART GIGA STORIES 99                                        SMART GIGA STORIES 99
# Utility-Power          PELCO 2                                                                    PELCO 2
# Loans                  Plentina                                                                  Plentina
# Utility-Power          VECO                                                                          VECO
# Prepaid Load           SMART GIGA STORIES 299                                      SMART GIGA STORIES 299
#                        GLOBE SURF4ALL249GP                                            GLOBE SURF4ALL249GP
# Other Prepaid Services GLOBE HOMESURF 199                                              GLOBE HOMESURF 199
# Loans                  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)
#                        CEPAT                                                                        CEPAT
# Utility-Power          PRESCO                                                                      PRESCO
# Tuition                PHINMA EDUCATION                                                  PHINMA EDUCATION
# Loans                  RFC LOAN                                                                  RFC LOAN
# Prepaid Load           GLOBE GO50                                                              GLOBE GO50
# E-Commerce             DRAGON PAY                                                              DRAGON PAY
# ...
# Airlines               CEBUPACIFIC                                                     24.359
# EMI                    Lazada                                                          24.242
# Loans                  CASHALO                                                         24.068
# Utility-Water          SB FINANCE                                                      23.776
# E-Wallet               ABRA                                                            23.529
# Insurance              AXAPHIL                                                         23.333
# Credit Card            BPI CREDITCARD                                                  23.256
# Loans                  PSBANK LOAN                                                     23.077
# Bank                   DISKARTECH 5001 to 15000                                        22.917
# Cable TV               BINANGONAN CABLE TV CORP                                        22.222
# Retailer Load          SMART RETAILER 500                                              22.222
# Tuition                ICCT COLLEGES                                                   22.222
# E-Commerce             SHOPEE                                                          21.488
# Loans                  AeonCredit                                                      21.036
# EMI                    SHOPEEPAY (DRAGONPAY)                                           21.019
# Credit Card            SBC MASTERCARD PESO                                             20.588
# Loans                  ZURICH                                                          20.000
# Utility-Water          TAGUM WATER                                                     20.000
# Bank                   DISKARTECH 1 to 5000                                            20.000
# Prepaid Load           TNT GIGA VIDEO 299                                              20.000
# Retailer Load          GLOBE RETAILER 500                                              20.000
# Collections            PERSONAL COLLECTION                                             20.000
# Utility-Water          SOUTH LUZON WATER                                               20.000
# Bank                   DISKARTECH 15001 to 25000                                       18.750
# Credit Card            METROBANK                                                       18.254
# Utility-Power          BENECO                                                          16.667
# Prepaid Load           SMART GIGA GAMES 99                                             16.667
# Postpaid Mobile        SUNCELLULAR                                                     16.000
# Utility-Water          ePRIME                                                          15.385
# Bank                   MAYBANK                                                         14.286
# Utility-Water          METRO ROXAS WATER DISTRICT                                      14.286
#                        COUNTRYWIDE WATER SERVICES                                      14.286
# Utility-Power          PELCO 3                                                         14.286
# Cable TV               PLANET CABLE                                                    13.333
# Prepaid Load           SUNXPRESSLOAD 150                                               12.500
# Utility-Power          CENPELCO                                                        11.111
# Prepaid Load           GLOBE 500                                                       11.111
# Cable TV               BICOL ONE BROADBAND SERVICE                                        NaN
#                        CENTRALLUZONCABLETV                                                NaN
#                        FIL PRODUCTS                                                       NaN
#                        GALAXY CABLE                                                       NaN
#                        PARASAT                                                            NaN
#                        SOUTH LUZON CABLE                                                  NaN
#                        USATV                                                              NaN
# Collections            ANJELMAN                                                           NaN
#                        APMC                                                               NaN
#                        Bills Payment - Honeycomb                                          NaN
#                        CAD REALTY                                                         NaN
#                        DINGDONG                                                           NaN
#                        Donation Key (GOLDEN HAVEN)                                        NaN
#                        GREENWEATH DEVELOPMENT CORP.                                       NaN
#                        JACQMAN                                                            NaN
#                        LOADMANNA, INC.                                                    NaN
#                        MASTERMAN                                                          NaN
#                        NETPLAY INC                                                        NaN
#                        PAYCOOLS                                                           NaN
#                        RAYMOND REALTY                                                     NaN
#                        RS MANAGEMENT                                                      NaN
#                        SMARTMAN                                                           NaN
#                        VTEC                                                               NaN
# Credit Card            AUB CREDITCARDS                                                    NaN
# E-Wallet               FORTUNE PAY                                                        NaN
#                        GETGO                                                              NaN
#                        HOMECREDIT PAY                                                     NaN
#                        MAGICPAY                                                           NaN
#                        NETBANK DEPOSIT                                                    NaN
#                        YAZZ                                                               NaN
# EMI                    ALLEASY                                                            NaN
#                        GRAB                                                               NaN
#                        RCBC myWallet                                                      NaN
# Gaming                 GAMECLUB 100                                                       NaN
#                        GAMECLUB 50                                                        NaN
#                        GARENA 100                                                         NaN
#                        GARENA 1000                                                        NaN
#                        GARENA 200                                                         NaN
#                        GARENA 50                                                          NaN
#                        STEAM 2640                                                         NaN
#                        STEAM 599                                                          NaN
#                        STEAM 60                                                           NaN
#                        STEAM 960                                                          NaN
#                        UniPin Voucher 100                                                 NaN
#                        UniPin Voucher 300                                                 NaN
# Government             BSP                                                                NaN
#                        MARINA (PISOPAY)                                                   NaN
#                        SOCIAL HOUSING FINANCE CORPORATION                                 NaN
# Insurance              CONNEXT MARKETING                                                  NaN
#                        INSULAR LIFE                                                       NaN
#                        PARAMOUNT                                                          NaN
# Internet               BICORE                                                             NaN
#                        WOOFY                                                              NaN
# Loans                  CARD INC                                                           NaN
#                        CHAILEASE BERJAYA                                                  NaN
#                        CTFSI                                                              NaN
#                        DS FINANCE                                                         NaN
#                        ENCORE LEASING AND FINANCE CORP                                    NaN
#                        FINASWIDE                                                          NaN
#                        FIRST STANDARD                                                     NaN
#                        FORBES LENDING                                                     NaN
#                        GLOBAL SME LOANS                                                   NaN
#                        GRAMEEN PILIPINAS MICROFINANCE                                     NaN
#                        LOAN STAR                                                          NaN
#                        MEGASAVER                                                          NaN
#                        OLM LENDING                                                        NaN
#                        PERAJET                                                            NaN
#                        SIMBAYANAN COOP                                                    NaN
#                        STO NINO DE CEBU FINANCE                                           NaN
# Other Prepaid Services CIGNAL 1000                                                        NaN
#                        CIGNAL 450                                                         NaN
#                        FAMLOAD VIDEO PLUS 199                                             NaN
#                        FAMLOAD VIDEO PLUS 999                                             NaN
#                        GLOBE HOMEWATCH 199                                                NaN
#                        NETFLIX 1000                                                       NaN
#                        NETFLIX 459                                                        NaN
# Prepaid Load           CHERRY LOAD 30                                                     NaN
#                        CHERRY LOAD 50                                                     NaN
#                        DITO E-LOAD 500                                                    NaN
#                        SUN TEXT UNLIMITED 150                                             NaN
#                        TOUCHMOBILE 30                                                     NaN
#                        TOUCHMOBILE 70                                                     NaN
# Retailer Load          GLOBE RETAILER 1000                                                NaN
#                        GLOBE RETAILER 1500                                                NaN
#                        GLOBE RETAILER 2000                                                NaN
#                        SMART RETAILER 1000                                                NaN
#                        SMART RETAILER 1500                                                NaN
#                        SMART RETAILER 2000                                                NaN
#                        SMART RETAILER 2500                                                NaN
# Tuition                GOLDEN FAITH ACADEMY                                               NaN
# Utility-Power          CAGELCO1                                                           NaN
#                        CASURECO 4                                                         NaN
#                        CASURECO2                                                          NaN
#                        CASURECO3                                                          NaN
#                        CEBECO 3                                                           NaN
#                        CELCOR                                                             NaN
#                        COTELCO                                                            NaN
#                        ISECO                                                              NaN
#                        LEYECO 2                                                           NaN
#                        LIMA ENERZONE                                                      NaN
#                        MOELCI 2                                                           NaN
#                        MORESCO 1                                                          NaN
#                        NEECO1                                                             NaN
#                        NEECO2 AREA2                                                       NaN
#                        NUVELCO                                                            NaN
#                        PANELCO1                                                           NaN
#                        PANELCO3                                                           NaN
#                        PELCO1                                                             NaN
#                        QUEZELCO1                                                          NaN
#                        SAJELCO                                                            NaN
#                        SORECO2                                                            NaN
#                        SubicEnerzone                                                      NaN
#                        TARELCO 1                                                          NaN
#                        TARLAC ELECTRIC INC                                                NaN
#                        ZAMECO2                                                            NaN
# Utility-Water          AQUA CENTRO                                                        NaN
#                        BAGUIO WATER                                                       NaN
#                        BOCAUE WATER DISTRICT                                              NaN
#                        BULACAN WATER                                                      NaN
#                        BULAKAN WATER                                                      NaN
#                        BUSTOS WATER DISTRICT                                              NaN
#                        CANDELARIA WATER DISTRICT                                          NaN
#                        CLARK WATER                                                        NaN
#                        GENSAN CITY WATER DISTRICT                                         NaN
#                        MABALACAT WATER                                                    NaN
#                        MACTAN ROCK INDUSTRIES, INC.                                       NaN
#                        PLARIDEL WATER                                                     NaN
#                        TANAY WATER DISTRICT                                               NaN
#                        TERESA WATER DISTRICT                                              NaN

# %%
# Calculate count of unique customers per sector and merchant
unique_customers_count = df.groupby(['sector', 'merchant_name'])['customer_id'].nunique()
unique_711mobile_count = df.groupby(['sector', 'merchant_name'])['mobile_num'].nunique()
unique_obsfstpd30_customer_count = df.groupby(['sector', 'merchant_name'])['customerId'].nunique()
unique_fstpd30_customer_count = df[df['fstpd30def']==1].groupby(['sector', 'merchant_name'])['customerId'].nunique()
sector_merchant_default_rate = round(df[df['fstpd30def']==1].groupby(['sector', 'merchant_name'])['customerId'].nunique() / df.groupby(['sector', 'merchant_name'])['customerId'].nunique()*100,3)

# Combine results into a DataFrame
result_df = pd.DataFrame({
    'Sector': sector_merchant_default_rate.index.get_level_values(0),
    'Merchant': sector_merchant_default_rate.index.get_level_values(1),
    'sector_merchant_default_rate':sector_merchant_default_rate,
    'Unique Customers Count': unique_customers_count,
    'unique 711mobile count': unique_711mobile_count,
    'Observed fstpd30 customer count': unique_obsfstpd30_customer_count,
    'fstpd30 Customer Count': unique_fstpd30_customer_count,
})

# result_df['sector_merchant_default_rate'] = round(result_df['fstpd30 Customer Count']/result_df['Observed fstpd30 customer count'] *100, 3) 
# Sort by Default Rate in descending order
result_df_sorted = result_df.sort_values(by='sector_merchant_default_rate', ascending=False)

pd.set_option('display.max_rows', None)
print("Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):")
sector_merchant_result = result_df_sorted.copy()
sector_merchant_result
# Out:
# Sector-wise and Merchant-wise Default Rate and Unique Customers Count (sorted from highest to lowest default rate):
#                                                                                  Sector  \
# sector                 merchant_name
# Loans                  SURECYCLE FINANCE                                          Loans
# Airlines               PAL (OTP Booking)                                       Airlines
# Credit Card            CHINABANK CREDITCARD                                 Credit Card
# Utility-Water          CARCAR WATER DISTRICT                              Utility-Water
# Collections            VIVAMAX INC                                          Collections
# Utility-Water          METRO LIPA WATER DISTRICT                          Utility-Water
# Prepaid Load           GLOBE GO400                                         Prepaid Load
# Collections            JOHNDORF                                             Collections
# Loans                  U PESO LENDING                                             Loans
#                        JUAN CASH                                                  Loans
#                        INSULAR SAVERS                                             Loans
#                        FUNDLINE                                                   Loans
# Gaming                 GAMECLUB 20                                               Gaming
# Cable TV               JMD CABLE NETWORK                                       Cable TV
# Prepaid Load           TM SURF4ALL249TM                                    Prepaid Load
# Gaming                 GAMECLUB 300                                              Gaming
#                        GAMECLUB 500                                              Gaming
# Loans                  CEBU CFI                                                   Loans
#                        CARD SME BANK                                              Loans
#                        BAGUIO BENGUET COMMUNITY CREDIT COOP                       Loans
# Utility-Power          INEC                                               Utility-Power
# Insurance              DIALEX                                                 Insurance
# Utility-Power          NEECO2 AREA1                                       Utility-Power
# Postpaid Land Lines    BAYANTEL                                     Postpaid Land Lines
# Loans                  BANCO ALABANG                                              Loans
# Utility-Power          NORECO2                                            Utility-Power
# Utility-Water          HAPPYWELLMANAGEMENT                                Utility-Water
# Loans                  SECOND PAY                                                 Loans
# Other Prepaid Services FAMLOAD VIDEO 199                         Other Prepaid Services
# Utility-Water          CDO WATER                                          Utility-Water
#                        OBANDO WATER                                       Utility-Water
# Utility-Power          PENELCO                                            Utility-Power
#                        MECO                                               Utility-Power
#                        CEPALCO                                            Utility-Power
# Utility-Water          MCWD (METRO CEBU)                                  Utility-Water
# Loans                  MOTORSTAR (Probikes)                                       Loans
#                        Motorcentral                                               Loans
# Utility-Power          TARELCO2                                           Utility-Power
# Prepaid Load           Giga Video+ 149                                     Prepaid Load
# Utility-Power          Bills Collection - Angeles Electric                Utility-Power
# Prepaid Load           SUNXPRESSLOAD 30                                    Prepaid Load
# Loans                  FILPROGRESS CREDIT                                         Loans
#                        CARD MRI RIZAL BANK                                        Loans
#                        CARD BANK INC                                              Loans
# Utility-Power          FLECO                                              Utility-Power
#                        ILIGAN LIGHT                                       Utility-Power
# Utility-Water          HIYAS WATER                                        Utility-Water
# Prepaid Load           SUN XPRESSLOAD 25                                   Prepaid Load
#                        SUNXPRESSLOAD 50                                    Prepaid Load
#                        SMART GIGA VIDEO 299                                Prepaid Load
# Loans                  NOVADECI                                                   Loans
# Utility-Water          CALUMPIT WATER                                     Utility-Water
# Loans                  SOUTH ASIALINK                                             Loans
# Utility-Water          Dagupan City Water District                        Utility-Water
# Other Prepaid Services CIGNAL 300                                Other Prepaid Services
#                        CIGNAL 600                                Other Prepaid Services
# Prepaid Load           DITO E-LOAD 300                                     Prepaid Load
# Other Prepaid Services FAMLOAD VIDEO 599                         Other Prepaid Services
#                        NETFLIX 550                               Other Prepaid Services
# Insurance              COCOLIFE                                               Insurance
# Utility-Power          OEDC                                               Utility-Power
# Gaming                 GARENA 500                                                Gaming
# Government             MULTIPAY (MANILA)                                     Government
# Utility-Water          STALUCIA                                           Utility-Water
# EMI                    TAGCASH                                                      EMI
# Cable TV               DASCA CABLE SERVICES INC                                Cable TV
# Gaming                 GARENA 300                                                Gaming
# Prepaid Load           TM SURF4ALL99TM                                     Prepaid Load
#                        GLOBE AMAX GO UNLI 30                               Prepaid Load
# Tuition                DRAGON SCHOOLS                                           Tuition
# Prepaid Load           TM ALL IN SURF 20 FB                                Prepaid Load
# E-Wallet               MAXIM                                                   E-Wallet
# Prepaid Load           GLOBE 50                                            Prepaid Load
# Airlines               PHILIPPINEAIRLINES                                      Airlines
# Prepaid Load           SUN TEXT UNLIMITED 50                               Prepaid Load
#                        GLOBE 300                                           Prepaid Load
#                        GLOBE SURF4ALL99GP                                  Prepaid Load
#                        GLOBE GO+129                                        Prepaid Load
# Utility-Power          ILECO1                                             Utility-Power
# E-Wallet               E-Money - EON                                           E-Wallet
# Loans                  AGRIBANK                                                   Loans
# Prepaid Load           GRAMEEN PILIPINAS MICROFINANCE                      Prepaid Load
# Gaming                 DRAGONGAMES                                               Gaming
# Utility-Power          SFELAPCO                                           Utility-Power
# Prepaid Load           TM EASYSURF 50                                      Prepaid Load
# Utility-Water          BPWATERWORKS                                       Utility-Water
# Prepaid Load           GLOBE 30                                            Prepaid Load
#                        SUNXPRESSLOAD 300                                   Prepaid Load
# Loans                  ORICO                                                      Loans
# Prepaid Load           ALL OUT SURF 30                                     Prepaid Load
# Loans                  MALAYAN BANK                                               Loans
# Prepaid Load           GIGA SURF 99                                        Prepaid Load
#                        GLOBE GOSURF 50                                     Prepaid Load
# Loans                  SKYPAY                                                     Loans
# Gaming                 GAMETIME                                                  Gaming
# Prepaid Load           GLOBE GO+149                                        Prepaid Load
#                        TM EZ70                                             Prepaid Load
#                        TNT Surf Saya 99                                    Prepaid Load
#                        SMART GIGA STORIES 99                               Prepaid Load
# Utility-Power          PELCO 2                                            Utility-Power
# Loans                  Plentina                                                   Loans
# Utility-Power          VECO                                               Utility-Power
# Prepaid Load           SMART GIGA STORIES 299                              Prepaid Load
#                        GLOBE SURF4ALL249GP                                 Prepaid Load
# Other Prepaid Services GLOBE HOMESURF 199                        Other Prepaid Services
# Loans                  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)                   Loans
#                        CEPAT                                                      Loans
# Utility-Power          PRESCO                                             Utility-Power
# Tuition                PHINMA EDUCATION                                         Tuition
# Loans                  RFC LOAN                                                   Loans
# Prepaid Load           GLOBE GO50                                          Prepaid Load
# E-Commerce             DRAGON PAY                                            E-Commerce
# Utility-Water          LAGUNA WATER                                       Utility-Water
# Prepaid Load           GLOBE GOSAKTO 140                                   Prepaid Load
#                        GLOBE GO+99                                         Prepaid Load
#                        TM ALL IN SURF 30                                   Prepaid Load
#                        GIGA SURF 50                                        Prepaid Load
#                        GLOBE GO120                                         Prepaid Load
# Loans                  CASHBEE                                                    Loans
# Prepaid Load           SMART REGULAR 30                                    Prepaid Load
# Loans                  FastLoan                                                   Loans
# Cable TV               Bills Payment - Royal Cable                             Cable TV
# Prepaid Load           GLOBE GO140                                         Prepaid Load
# Tuition                NATIONAL TEACHERS COLLEGE                                Tuition
# Collections            CBN ASIA                                             Collections
# Prepaid Load           GLOBE Autoload                                      Prepaid Load
# EMI                    Paymaya                                                      EMI
# Cable TV               SKYLINE CATV INDUSTRIES INC                             Cable TV
# Utility-Water          SUBICWATER                                         Utility-Water
# Prepaid Load           SMART REGULAR 115                                   Prepaid Load
# Bank                   UNIONBANK                                                   Bank
# Prepaid Load           GLOBE GOSAKTO 120                                   Prepaid Load
#                        GLOBE GOSAKTO 90                                    Prepaid Load
# Loans                  GLOBAL DOMINION                                            Loans
# Prepaid Load           GLOBE GO90                                          Prepaid Load
# Cable TV               SKYCABLE                                                Cable TV
#                        PLANET CABLE / MEDIASCAPE-CIGNAL                        Cable TV
# Loans                  SUMISHO                                                    Loans
# E-Commerce             AGODA                                                 E-Commerce
# Loans                  DRAGON LOANS                                               Loans
# Prepaid Load           SMART REGULAR 60                                    Prepaid Load
# Government             NBI                                                   Government
# Loans                  ASIALINK                                                   Loans
# Postpaid Land Lines    GLOBELINES                                   Postpaid Land Lines
# Loans                  PAYSO                                                      Loans
# Other Prepaid Services FAMLOAD VIDEO 999                         Other Prepaid Services
# Cable TV               ASIAN VISION CABLE                                      Cable TV
# Prepaid Load           GLOBE GO+250                                        Prepaid Load
# Utility-Power          LUELCO                                             Utility-Power
# Utility-Water          MIWD                                               Utility-Water
# Cable TV               KABAYAN CABLE CORP                                      Cable TV
# Prepaid Load           SUNXPRESSLOAD 75                                    Prepaid Load
# Utility-Power          DAVAOLIGHT                                         Utility-Power
#                        DASURECO                                           Utility-Power
# Loans                  COUNTRY FUNDERS                                            Loans
# Utility-Power          ZAMECO1                                            Utility-Power
# Loans                  CVM FINANCE                                                Loans
# Utility-Water          MANILAWATER PHILVENTURES                           Utility-Water
# Postpaid Land Lines    PLDT                                         Postpaid Land Lines
# E-Wallet               PISOPAY                                                 E-Wallet
# Prepaid Load           SMART REGULAR 500                                   Prepaid Load
#                        SUNXPRESSLOAD 100                                   Prepaid Load
#                        DITO E-LOAD 200                                     Prepaid Load
#                        DITO E-LOAD 100                                     Prepaid Load
#                        GLOBE 100                                           Prepaid Load
# EMI                    Coins.ph                                                     EMI
# Loans                  FLEXI FINANCE                                              Loans
# Credit Card            ROBINSONBANK CREDITCARD                              Credit Card
# Government             MARINA                                                Government
# Loans                  ACOM                                                       Loans
# Remittance             Palawan Padala                                        Remittance
# Loans                  PAYEXPRESS LOAN                                            Loans
# EMI                    GCash                                                        EMI
# Internet               CONVERGEICT                                             Internet
# Prepaid Load           UNLICALL 15                                         Prepaid Load
# EMI                    HELLO MONEY                                                  EMI
# Prepaid Load           SMART REGULAR 300                                   Prepaid Load
#                        TNT Giga Video 50                                   Prepaid Load
# Utility-Water          MAYNILAD                                           Utility-Water
# Gaming                 METROTURF                                                 Gaming
# E-Commerce             NETFLIX DragonPay                                     E-Commerce
# Government             NSOHELPLINE.COM                                       Government
# Transpo or Toll        EASYTRIP                                         Transpo or Toll
# Utility-Water          PRIMEWATER                                         Utility-Water
#                        MANILAWATER                                        Utility-Water
# Prepaid Load           GLOBE 70                                            Prepaid Load
#                        TNT Giga Video 99                                   Prepaid Load
# Utility-Power          CEBECO2                                            Utility-Power
# Government             BUREAU OF QUARANTINE                                  Government
# Collections            PAYEXPRESS TICKETS                                   Collections
# Utility-Power          BATELEC1                                           Utility-Power
# Prepaid Load           TOUCHMOBILE 50                                      Prepaid Load
#                        SUN TU200 200                                       Prepaid Load
# Loans                  NWOW                                                       Loans
# Transpo or Toll        RFID                                             Transpo or Toll
# Loans                  CHINATRUST                                                 Loans
# Bank                   CIMB                                                        Bank
# Postpaid Mobile        GHPHONE                                          Postpaid Mobile
# Utility-Power          BATELEC2                                           Utility-Power
# Loans                  MITSUKOSHI                                                 Loans
#                        TALA                                                       Loans
# Government             DFA                                                   Government
# Loans                  LENDPINOY                                                  Loans
# Cable TV               CABLELINK                                               Cable TV
# Loans                  HOME CREDIT                                                Loans
# Government             MYEG PH                                               Government
# Utility-Water          GOODHANDSWATER                                     Utility-Water
# Transpo or Toll        BARKOTA                                          Transpo or Toll
# Credit Card            BANK OF COMMERCE CREDIT CARD                         Credit Card
# Loans                  UNIONBANK QUICKLOANS                                       Loans
# Postpaid Mobile        SMART                                            Postpaid Mobile
# Gaming                 STEAM 299                                                 Gaming
# Utility-Water          METRO DUMAGUETE WATER                              Utility-Water
# Prepaid Load           GLOBE GO+400                                        Prepaid Load
# Utility-Water          WATERS PH                                          Utility-Water
#                        FIRST PEAK                                         Utility-Water
# Gaming                 STEAM 120                                                 Gaming
# Utility-Power          DECORP                                             Utility-Power
# Utility-Water          LAGUNA WATER DISTRICT                              Utility-Water
# Utility-Power          CAPELCO                                            Utility-Power
# Prepaid Load           GLOBE Autoload 350                                  Prepaid Load
# Airlines               CEBUPACIFIC                                             Airlines
# EMI                    Lazada                                                       EMI
# Loans                  CASHALO                                                    Loans
# Utility-Water          SB FINANCE                                         Utility-Water
# E-Wallet               ABRA                                                    E-Wallet
# Insurance              AXAPHIL                                                Insurance
# Credit Card            BPI CREDITCARD                                       Credit Card
# Loans                  PSBANK LOAN                                                Loans
# Bank                   DISKARTECH 5001 to 15000                                    Bank
# Cable TV               BINANGONAN CABLE TV CORP                                Cable TV
# Retailer Load          SMART RETAILER 500                                 Retailer Load
# Tuition                ICCT COLLEGES                                            Tuition
# E-Commerce             SHOPEE                                                E-Commerce
# Loans                  AeonCredit                                                 Loans
# EMI                    SHOPEEPAY (DRAGONPAY)                                        EMI
# Credit Card            SBC MASTERCARD PESO                                  Credit Card
# Loans                  ZURICH                                                     Loans
# Utility-Water          TAGUM WATER                                        Utility-Water
# Bank                   DISKARTECH 1 to 5000                                        Bank
# Prepaid Load           TNT GIGA VIDEO 299                                  Prepaid Load
# Retailer Load          GLOBE RETAILER 500                                 Retailer Load
# Collections            PERSONAL COLLECTION                                  Collections
# Utility-Water          SOUTH LUZON WATER                                  Utility-Water
# Bank                   DISKARTECH 15001 to 25000                                   Bank
# Credit Card            METROBANK                                            Credit Card
# Utility-Power          BENECO                                             Utility-Power
# Prepaid Load           SMART GIGA GAMES 99                                 Prepaid Load
# Postpaid Mobile        SUNCELLULAR                                      Postpaid Mobile
# Utility-Water          ePRIME                                             Utility-Water
# Bank                   MAYBANK                                                     Bank
# Utility-Water          METRO ROXAS WATER DISTRICT                         Utility-Water
#                        COUNTRYWIDE WATER SERVICES                         Utility-Water
# Utility-Power          PELCO 3                                            Utility-Power
# Cable TV               PLANET CABLE                                            Cable TV
# Prepaid Load           SUNXPRESSLOAD 150                                   Prepaid Load
# Utility-Power          CENPELCO                                           Utility-Power
# Prepaid Load           GLOBE 500                                           Prepaid Load
# Cable TV               BICOL ONE BROADBAND SERVICE                             Cable TV
#                        CENTRALLUZONCABLETV                                     Cable TV
#                        FIL PRODUCTS                                            Cable TV
#                        GALAXY CABLE                                            Cable TV
#                        PARASAT                                                 Cable TV
#                        SOUTH LUZON CABLE                                       Cable TV
#                        USATV                                                   Cable TV
# Collections            ANJELMAN                                             Collections
#                        APMC                                                 Collections
#                        Bills Payment - Honeycomb                            Collections
#                        CAD REALTY                                           Collections
#                        DINGDONG                                             Collections
#                        Donation Key (GOLDEN HAVEN)                          Collections
#                        GREENWEATH DEVELOPMENT CORP.                         Collections
#                        JACQMAN                                              Collections
#                        LOADMANNA, INC.                                      Collections
#                        MASTERMAN                                            Collections
#                        NETPLAY INC                                          Collections
#                        PAYCOOLS                                             Collections
#                        RAYMOND REALTY                                       Collections
#                        RS MANAGEMENT                                        Collections
#                        SMARTMAN                                             Collections
#                        VTEC                                                 Collections
# Credit Card            AUB CREDITCARDS                                      Credit Card
# E-Wallet               FORTUNE PAY                                             E-Wallet
#                        GETGO                                                   E-Wallet
#                        HOMECREDIT PAY                                          E-Wallet
#                        MAGICPAY                                                E-Wallet
#                        NETBANK DEPOSIT                                         E-Wallet
#                        YAZZ                                                    E-Wallet
# EMI                    ALLEASY                                                      EMI
#                        GRAB                                                         EMI
#                        RCBC myWallet                                                EMI
# Gaming                 GAMECLUB 100                                              Gaming
#                        GAMECLUB 50                                               Gaming
#                        GARENA 100                                                Gaming
#                        GARENA 1000                                               Gaming
#                        GARENA 200                                                Gaming
#                        GARENA 50                                                 Gaming
#                        STEAM 2640                                                Gaming
#                        STEAM 599                                                 Gaming
#                        STEAM 60                                                  Gaming
#                        STEAM 960                                                 Gaming
#                        UniPin Voucher 100                                        Gaming
#                        UniPin Voucher 300                                        Gaming
# Government             BSP                                                   Government
#                        MARINA (PISOPAY)                                      Government
#                        SOCIAL HOUSING FINANCE CORPORATION                    Government
# Insurance              CONNEXT MARKETING                                      Insurance
#                        INSULAR LIFE                                           Insurance
#                        PARAMOUNT                                              Insurance
# Internet               BICORE                                                  Internet
#                        WOOFY                                                   Internet
# Loans                  CARD INC                                                   Loans
#                        CHAILEASE BERJAYA                                          Loans
#                        CTFSI                                                      Loans
#                        DS FINANCE                                                 Loans
#                        ENCORE LEASING AND FINANCE CORP                            Loans
#                        FINASWIDE                                                  Loans
#                        FIRST STANDARD                                             Loans
#                        FORBES LENDING                                             Loans
#                        GLOBAL SME LOANS                                           Loans
#                        GRAMEEN PILIPINAS MICROFINANCE                             Loans
#                        LOAN STAR                                                  Loans
#                        MEGASAVER                                                  Loans
#                        OLM LENDING                                                Loans
#                        PERAJET                                                    Loans
#                        SIMBAYANAN COOP                                            Loans
#                        STO NINO DE CEBU FINANCE                                   Loans
# Other Prepaid Services CIGNAL 1000                               Other Prepaid Services
#                        CIGNAL 450                                Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 199                    Other Prepaid Services
#                        FAMLOAD VIDEO PLUS 999                    Other Prepaid Services
#                        GLOBE HOMEWATCH 199                       Other Prepaid Services
#                        NETFLIX 1000                              Other Prepaid Services
#                        NETFLIX 459                               Other Prepaid Services
# Prepaid Load           CHERRY LOAD 30                                      Prepaid Load
#                        CHERRY LOAD 50                                      Prepaid Load
#                        DITO E-LOAD 500                                     Prepaid Load
#                        SUN TEXT UNLIMITED 150                              Prepaid Load
#                        TOUCHMOBILE 30                                      Prepaid Load
#                        TOUCHMOBILE 70                                      Prepaid Load
# Retailer Load          GLOBE RETAILER 1000                                Retailer Load
#                        GLOBE RETAILER 1500                                Retailer Load
#                        GLOBE RETAILER 2000                                Retailer Load
#                        SMART RETAILER 1000                                Retailer Load
#                        SMART RETAILER 1500                                Retailer Load
#                        SMART RETAILER 2000                                Retailer Load
#                        SMART RETAILER 2500                                Retailer Load
# Tuition                GOLDEN FAITH ACADEMY                                     Tuition
# Utility-Power          CAGELCO1                                           Utility-Power
#                        CASURECO 4                                         Utility-Power
#                        CASURECO2                                          Utility-Power
#                        CASURECO3                                          Utility-Power
#                        CEBECO 3                                           Utility-Power
#                        CELCOR                                             Utility-Power
#                        COTELCO                                            Utility-Power
#                        ISECO                                              Utility-Power
#                        LEYECO 2                                           Utility-Power
#                        LIMA ENERZONE                                      Utility-Power
#                        MOELCI 2                                           Utility-Power
#                        MORESCO 1                                          Utility-Power
#                        NEECO1                                             Utility-Power
#                        NEECO2 AREA2                                       Utility-Power
#                        NUVELCO                                            Utility-Power
#                        PANELCO1                                           Utility-Power
#                        PANELCO3                                           Utility-Power
#                        PELCO1                                             Utility-Power
#                        QUEZELCO1                                          Utility-Power
#                        SAJELCO                                            Utility-Power
#                        SORECO2                                            Utility-Power
#                        SubicEnerzone                                      Utility-Power
#                        TARELCO 1                                          Utility-Power
#                        TARLAC ELECTRIC INC                                Utility-Power
#                        ZAMECO2                                            Utility-Power
# Utility-Water          AQUA CENTRO                                        Utility-Water
#                        BAGUIO WATER                                       Utility-Water
#                        BOCAUE WATER DISTRICT                              Utility-Water
#                        BULACAN WATER                                      Utility-Water
#                        BULAKAN WATER                                      Utility-Water
#                        BUSTOS WATER DISTRICT                              Utility-Water
#                        CANDELARIA WATER DISTRICT                          Utility-Water
#                        CLARK WATER                                        Utility-Water
#                        GENSAN CITY WATER DISTRICT                         Utility-Water
#                        MABALACAT WATER                                    Utility-Water
#                        MACTAN ROCK INDUSTRIES, INC.                       Utility-Water
#                        PLARIDEL WATER                                     Utility-Water
#                        TANAY WATER DISTRICT                               Utility-Water
#                        TERESA WATER DISTRICT                              Utility-Water
#
#                                                                                                  Merchant  \
# sector                 merchant_name
# Loans                  SURECYCLE FINANCE                                                SURECYCLE FINANCE
# Airlines               PAL (OTP Booking)                                                PAL (OTP Booking)
# Credit Card            CHINABANK CREDITCARD                                          CHINABANK CREDITCARD
# Utility-Water          CARCAR WATER DISTRICT                                        CARCAR WATER DISTRICT
# Collections            VIVAMAX INC                                                            VIVAMAX INC
# Utility-Water          METRO LIPA WATER DISTRICT                                METRO LIPA WATER DISTRICT
# Prepaid Load           GLOBE GO400                                                            GLOBE GO400
# Collections            JOHNDORF                                                                  JOHNDORF
# Loans                  U PESO LENDING                                                      U PESO LENDING
#                        JUAN CASH                                                                JUAN CASH
#                        INSULAR SAVERS                                                      INSULAR SAVERS
#                        FUNDLINE                                                                  FUNDLINE
# Gaming                 GAMECLUB 20                                                            GAMECLUB 20
# Cable TV               JMD CABLE NETWORK                                                JMD CABLE NETWORK
# Prepaid Load           TM SURF4ALL249TM                                                  TM SURF4ALL249TM
# Gaming                 GAMECLUB 300                                                          GAMECLUB 300
#                        GAMECLUB 500                                                          GAMECLUB 500
# Loans                  CEBU CFI                                                                  CEBU CFI
#                        CARD SME BANK                                                        CARD SME BANK
#                        BAGUIO BENGUET COMMUNITY CREDIT COOP          BAGUIO BENGUET COMMUNITY CREDIT COOP
# Utility-Power          INEC                                                                          INEC
# Insurance              DIALEX                                                                      DIALEX
# Utility-Power          NEECO2 AREA1                                                          NEECO2 AREA1
# Postpaid Land Lines    BAYANTEL                                                                  BAYANTEL
# Loans                  BANCO ALABANG                                                        BANCO ALABANG
# Utility-Power          NORECO2                                                                    NORECO2
# Utility-Water          HAPPYWELLMANAGEMENT                                            HAPPYWELLMANAGEMENT
# Loans                  SECOND PAY                                                              SECOND PAY
# Other Prepaid Services FAMLOAD VIDEO 199                                                FAMLOAD VIDEO 199
# Utility-Water          CDO WATER                                                                CDO WATER
#                        OBANDO WATER                                                          OBANDO WATER
# Utility-Power          PENELCO                                                                    PENELCO
#                        MECO                                                                          MECO
#                        CEPALCO                                                                    CEPALCO
# Utility-Water          MCWD (METRO CEBU)                                                MCWD (METRO CEBU)
# Loans                  MOTORSTAR (Probikes)                                          MOTORSTAR (Probikes)
#                        Motorcentral                                                          Motorcentral
# Utility-Power          TARELCO2                                                                  TARELCO2
# Prepaid Load           Giga Video+ 149                                                    Giga Video+ 149
# Utility-Power          Bills Collection - Angeles Electric            Bills Collection - Angeles Electric
# Prepaid Load           SUNXPRESSLOAD 30                                                  SUNXPRESSLOAD 30
# Loans                  FILPROGRESS CREDIT                                              FILPROGRESS CREDIT
#                        CARD MRI RIZAL BANK                                            CARD MRI RIZAL BANK
#                        CARD BANK INC                                                        CARD BANK INC
# Utility-Power          FLECO                                                                        FLECO
#                        ILIGAN LIGHT                                                          ILIGAN LIGHT
# Utility-Water          HIYAS WATER                                                            HIYAS WATER
# Prepaid Load           SUN XPRESSLOAD 25                                                SUN XPRESSLOAD 25
#                        SUNXPRESSLOAD 50                                                  SUNXPRESSLOAD 50
#                        SMART GIGA VIDEO 299                                          SMART GIGA VIDEO 299
# Loans                  NOVADECI                                                                  NOVADECI
# Utility-Water          CALUMPIT WATER                                                      CALUMPIT WATER
# Loans                  SOUTH ASIALINK                                                      SOUTH ASIALINK
# Utility-Water          Dagupan City Water District                            Dagupan City Water District
# Other Prepaid Services CIGNAL 300                                                              CIGNAL 300
#                        CIGNAL 600                                                              CIGNAL 600
# Prepaid Load           DITO E-LOAD 300                                                    DITO E-LOAD 300
# Other Prepaid Services FAMLOAD VIDEO 599                                                FAMLOAD VIDEO 599
#                        NETFLIX 550                                                            NETFLIX 550
# Insurance              COCOLIFE                                                                  COCOLIFE
# Utility-Power          OEDC                                                                          OEDC
# Gaming                 GARENA 500                                                              GARENA 500
# Government             MULTIPAY (MANILA)                                                MULTIPAY (MANILA)
# Utility-Water          STALUCIA                                                                  STALUCIA
# EMI                    TAGCASH                                                                    TAGCASH
# Cable TV               DASCA CABLE SERVICES INC                                  DASCA CABLE SERVICES INC
# Gaming                 GARENA 300                                                              GARENA 300
# Prepaid Load           TM SURF4ALL99TM                                                    TM SURF4ALL99TM
#                        GLOBE AMAX GO UNLI 30                                        GLOBE AMAX GO UNLI 30
# Tuition                DRAGON SCHOOLS                                                      DRAGON SCHOOLS
# Prepaid Load           TM ALL IN SURF 20 FB                                          TM ALL IN SURF 20 FB
# E-Wallet               MAXIM                                                                        MAXIM
# Prepaid Load           GLOBE 50                                                                  GLOBE 50
# Airlines               PHILIPPINEAIRLINES                                              PHILIPPINEAIRLINES
# Prepaid Load           SUN TEXT UNLIMITED 50                                        SUN TEXT UNLIMITED 50
#                        GLOBE 300                                                                GLOBE 300
#                        GLOBE SURF4ALL99GP                                              GLOBE SURF4ALL99GP
#                        GLOBE GO+129                                                          GLOBE GO+129
# Utility-Power          ILECO1                                                                      ILECO1
# E-Wallet               E-Money - EON                                                        E-Money - EON
# Loans                  AGRIBANK                                                                  AGRIBANK
# Prepaid Load           GRAMEEN PILIPINAS MICROFINANCE                      GRAMEEN PILIPINAS MICROFINANCE
# Gaming                 DRAGONGAMES                                                            DRAGONGAMES
# Utility-Power          SFELAPCO                                                                  SFELAPCO
# Prepaid Load           TM EASYSURF 50                                                      TM EASYSURF 50
# Utility-Water          BPWATERWORKS                                                          BPWATERWORKS
# Prepaid Load           GLOBE 30                                                                  GLOBE 30
#                        SUNXPRESSLOAD 300                                                SUNXPRESSLOAD 300
# Loans                  ORICO                                                                        ORICO
# Prepaid Load           ALL OUT SURF 30                                                    ALL OUT SURF 30
# Loans                  MALAYAN BANK                                                          MALAYAN BANK
# Prepaid Load           GIGA SURF 99                                                          GIGA SURF 99
#                        GLOBE GOSURF 50                                                    GLOBE GOSURF 50
# Loans                  SKYPAY                                                                      SKYPAY
# Gaming                 GAMETIME                                                                  GAMETIME
# Prepaid Load           GLOBE GO+149                                                          GLOBE GO+149
#                        TM EZ70                                                                    TM EZ70
#                        TNT Surf Saya 99                                                  TNT Surf Saya 99
#                        SMART GIGA STORIES 99                                        SMART GIGA STORIES 99
# Utility-Power          PELCO 2                                                                    PELCO 2
# Loans                  Plentina                                                                  Plentina
# Utility-Power          VECO                                                                          VECO
# Prepaid Load           SMART GIGA STORIES 299                                      SMART GIGA STORIES 299
#                        GLOBE SURF4ALL249GP                                            GLOBE SURF4ALL249GP
# Other Prepaid Services GLOBE HOMESURF 199                                              GLOBE HOMESURF 199
# Loans                  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)  PAYMENT INNOVATION INC. (PAYCOOLS LOANS)
#                        CEPAT                                                                        CEPAT
# Utility-Power          PRESCO                                                                      PRESCO
# Tuition                PHINMA EDUCATION                                                  PHINMA EDUCATION
# Loans                  RFC LOAN                                                                  RFC LOAN
# Prepaid Load           GLOBE GO50                                                              GLOBE GO50
# E-Commerce             DRAGON PAY                                                              DRAGON PAY
# ...
# Postpaid Mobile        SMART                                                       35.0
# Gaming                 STEAM 299                                                    1.0
# Utility-Water          METRO DUMAGUETE WATER                                        1.0
# Prepaid Load           GLOBE GO+400                                                 1.0
# Utility-Water          WATERS PH                                                    1.0
#                        FIRST PEAK                                                   1.0
# Gaming                 STEAM 120                                                    1.0
# Utility-Power          DECORP                                                       1.0
# Utility-Water          LAGUNA WATER DISTRICT                                        4.0
# Utility-Power          CAPELCO                                                      1.0
# Prepaid Load           GLOBE Autoload 350                                          17.0
# Airlines               CEBUPACIFIC                                                 76.0
# EMI                    Lazada                                                       8.0
# Loans                  CASHALO                                                    213.0
# Utility-Water          SB FINANCE                                                  68.0
# E-Wallet               ABRA                                                         8.0
# Insurance              AXAPHIL                                                      7.0
# Credit Card            BPI CREDITCARD                                              20.0
# Loans                  PSBANK LOAN                                                  9.0
# Bank                   DISKARTECH 5001 to 15000                                    11.0
# Cable TV               BINANGONAN CABLE TV CORP                                     2.0
# Retailer Load          SMART RETAILER 500                                           4.0
# Tuition                ICCT COLLEGES                                                2.0
# E-Commerce             SHOPEE                                                      52.0
# Loans                  AeonCredit                                                  65.0
# EMI                    SHOPEEPAY (DRAGONPAY)                                       33.0
# Credit Card            SBC MASTERCARD PESO                                         21.0
# Loans                  ZURICH                                                       1.0
# Utility-Water          TAGUM WATER                                                  3.0
# Bank                   DISKARTECH 1 to 5000                                        12.0
# Prepaid Load           TNT GIGA VIDEO 299                                           1.0
# Retailer Load          GLOBE RETAILER 500                                           2.0
# Collections            PERSONAL COLLECTION                                          1.0
# Utility-Water          SOUTH LUZON WATER                                            1.0
# Bank                   DISKARTECH 15001 to 25000                                    6.0
# Credit Card            METROBANK                                                   23.0
# Utility-Power          BENECO                                                       2.0
# Prepaid Load           SMART GIGA GAMES 99                                          4.0
# Postpaid Mobile        SUNCELLULAR                                                  4.0
# Utility-Water          ePRIME                                                       2.0
# Bank                   MAYBANK                                                      1.0
# Utility-Water          METRO ROXAS WATER DISTRICT                                   1.0
#                        COUNTRYWIDE WATER SERVICES                                   1.0
# Utility-Power          PELCO 3                                                      1.0
# Cable TV               PLANET CABLE                                                 2.0
# Prepaid Load           SUNXPRESSLOAD 150                                            1.0
# Utility-Power          CENPELCO                                                     1.0
# Prepaid Load           GLOBE 500                                                    1.0
# Cable TV               BICOL ONE BROADBAND SERVICE                                  NaN
#                        CENTRALLUZONCABLETV                                          NaN
#                        FIL PRODUCTS                                                 NaN
#                        GALAXY CABLE                                                 NaN
#                        PARASAT                                                      NaN
#                        SOUTH LUZON CABLE                                            NaN
#                        USATV                                                        NaN
# Collections            ANJELMAN                                                     NaN
#                        APMC                                                         NaN
#                        Bills Payment - Honeycomb                                    NaN
#                        CAD REALTY                                                   NaN
#                        DINGDONG                                                     NaN
#                        Donation Key (GOLDEN HAVEN)                                  NaN
#                        GREENWEATH DEVELOPMENT CORP.                                 NaN
#                        JACQMAN                                                      NaN
#                        LOADMANNA, INC.                                              NaN
#                        MASTERMAN                                                    NaN
#                        NETPLAY INC                                                  NaN
#                        PAYCOOLS                                                     NaN
#                        RAYMOND REALTY                                               NaN
#                        RS MANAGEMENT                                                NaN
#                        SMARTMAN                                                     NaN
#                        VTEC                                                         NaN
# Credit Card            AUB CREDITCARDS                                              NaN
# E-Wallet               FORTUNE PAY                                                  NaN
#                        GETGO                                                        NaN
#                        HOMECREDIT PAY                                               NaN
#                        MAGICPAY                                                     NaN
#                        NETBANK DEPOSIT                                              NaN
#                        YAZZ                                                         NaN
# EMI                    ALLEASY                                                      NaN
#                        GRAB                                                         NaN
#                        RCBC myWallet                                                NaN
# Gaming                 GAMECLUB 100                                                 NaN
#                        GAMECLUB 50                                                  NaN
#                        GARENA 100                                                   NaN
#                        GARENA 1000                                                  NaN
#                        GARENA 200                                                   NaN
#                        GARENA 50                                                    NaN
#                        STEAM 2640                                                   NaN
#                        STEAM 599                                                    NaN
#                        STEAM 60                                                     NaN
#                        STEAM 960                                                    NaN
#                        UniPin Voucher 100                                           NaN
#                        UniPin Voucher 300                                           NaN
# Government             BSP                                                          NaN
#                        MARINA (PISOPAY)                                             NaN
#                        SOCIAL HOUSING FINANCE CORPORATION                           NaN
# Insurance              CONNEXT MARKETING                                            NaN
#                        INSULAR LIFE                                                 NaN
#                        PARAMOUNT                                                    NaN
# Internet               BICORE                                                       NaN
#                        WOOFY                                                        NaN
# Loans                  CARD INC                                                     NaN
#                        CHAILEASE BERJAYA                                            NaN
#                        CTFSI                                                        NaN
#                        DS FINANCE                                                   NaN
#                        ENCORE LEASING AND FINANCE CORP                              NaN
#                        FINASWIDE                                                    NaN
#                        FIRST STANDARD                                               NaN
#                        FORBES LENDING                                               NaN
#                        GLOBAL SME LOANS                                             NaN
#                        GRAMEEN PILIPINAS MICROFINANCE                               NaN
#                        LOAN STAR                                                    NaN
#                        MEGASAVER                                                    NaN
#                        OLM LENDING                                                  NaN
#                        PERAJET                                                      NaN
#                        SIMBAYANAN COOP                                              NaN
#                        STO NINO DE CEBU FINANCE                                     NaN
# Other Prepaid Services CIGNAL 1000                                                  NaN
#                        CIGNAL 450                                                   NaN
#                        FAMLOAD VIDEO PLUS 199                                       NaN
#                        FAMLOAD VIDEO PLUS 999                                       NaN
#                        GLOBE HOMEWATCH 199                                          NaN
#                        NETFLIX 1000                                                 NaN
#                        NETFLIX 459                                                  NaN
# Prepaid Load           CHERRY LOAD 30                                               NaN
#                        CHERRY LOAD 50                                               NaN
#                        DITO E-LOAD 500                                              NaN
#                        SUN TEXT UNLIMITED 150                                       NaN
#                        TOUCHMOBILE 30                                               NaN
#                        TOUCHMOBILE 70                                               NaN
# Retailer Load          GLOBE RETAILER 1000                                          NaN
#                        GLOBE RETAILER 1500                                          NaN
#                        GLOBE RETAILER 2000                                          NaN
#                        SMART RETAILER 1000                                          NaN
#                        SMART RETAILER 1500                                          NaN
#                        SMART RETAILER 2000                                          NaN
#                        SMART RETAILER 2500                                          NaN
# Tuition                GOLDEN FAITH ACADEMY                                         NaN
# Utility-Power          CAGELCO1                                                     NaN
#                        CASURECO 4                                                   NaN
#                        CASURECO2                                                    NaN
#                        CASURECO3                                                    NaN
#                        CEBECO 3                                                     NaN
#                        CELCOR                                                       NaN
#                        COTELCO                                                      NaN
#                        ISECO                                                        NaN
#                        LEYECO 2                                                     NaN
#                        LIMA ENERZONE                                                NaN
#                        MOELCI 2                                                     NaN
#                        MORESCO 1                                                    NaN
#                        NEECO1                                                       NaN
#                        NEECO2 AREA2                                                 NaN
#                        NUVELCO                                                      NaN
#                        PANELCO1                                                     NaN
#                        PANELCO3                                                     NaN
#                        PELCO1                                                       NaN
#                        QUEZELCO1                                                    NaN
#                        SAJELCO                                                      NaN
#                        SORECO2                                                      NaN
#                        SubicEnerzone                                                NaN
#                        TARELCO 1                                                    NaN
#                        TARLAC ELECTRIC INC                                          NaN
#                        ZAMECO2                                                      NaN
# Utility-Water          AQUA CENTRO                                                  NaN
#                        BAGUIO WATER                                                 NaN
#                        BOCAUE WATER DISTRICT                                        NaN
#                        BULACAN WATER                                                NaN
#                        BULAKAN WATER                                                NaN
#                        BUSTOS WATER DISTRICT                                        NaN
#                        CANDELARIA WATER DISTRICT                                    NaN
#                        CLARK WATER                                                  NaN
#                        GENSAN CITY WATER DISTRICT                                   NaN
#                        MABALACAT WATER                                              NaN
#                        MACTAN ROCK INDUSTRIES, INC.                                 NaN
#                        PLARIDEL WATER                                               NaN
#                        TANAY WATER DISTRICT                                         NaN
#                        TERESA WATER DISTRICT                                        NaN

# %%
# Create a Pandas Excel writer using ExcelWriter
excel_file = r'C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Personal\research\711_Analysis\Data\sector_analysis.xlsx'
with pd.ExcelWriter(excel_file) as writer:
    # Write each DataFrame to a separate sheet
    sector_result.to_excel(writer, sheet_name='Sector Result', index=False)
    sector_merchant_result.to_excel(writer, sheet_name='Sector Merchant Result', index=False)

print(f"Excel file '{excel_file}' has been created with two sheets.")
# Out:
# Excel file 'C:\Users\DwaipayanChakroborti\OneDrive - Tonik Financial Pte Ltd\MyStuff\Personal\research\711_Analysis\Data\sector_analysis.xlsx' has been created with two sheets.
